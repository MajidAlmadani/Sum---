# %%
# !pip install ultralytics easyocr opencv-python matplotlib

# %%
# !unzip /content/License-Characters-by-2-27classes.zip -d /content/Dataset/

# %%
a2eL = {
    'ا': 'A',
    'ب': 'B',
    'ج': 'J',
    'د': 'D',
    'ر': 'R',
    'س': 'S',
    'ص': 'S',
    'ط': 'T',
    'ع': 'T',
    'ق': 'G',
    'ك': 'K',
    'ل': 'L',
    'م': 'Z',
    'ن': 'N',
    'ه': 'H',
    'و': 'O',
    'ي': 'E'
}

e2aL = {
     'A':'ا',
     'B':'ب',
     'J':'ج',
     'D':'د',
     'R':'ر',
     'S':'س',
     'S':'ص',
     'T':'ط',
     'T':'ع',
     'G':'ق',
     'K':'ك',
     'L':'ل',
     'Z':'م',
     'N':'ن',
     'H':'ه',
     'O':'و',
     'E':'ي',
}

a2eN = {
    '٠': '0',
    '١': '1',
    '٢': '2',
    '٣': '3',
    '٤': '4',
    '٥': '5',
    '٦': '6',
    '٧': '7',
    '٨': '8',
    '٩': '9'
}

e2aN = {
    '0':'٠',
    '1':'١',
    '2':'٢',
    '3':'٣',
    '4':'٤',
    '5':'٥',
    '6':'٦',
    '7':'٧',
    '8':'٨',
    '9':'٩',
}

# %%
from transformers import AutoModel, AutoTokenizer, AutoProcessor
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr
import os
from PIL import Image


# processer = AutoProcessor.from_pretrained('stepfun-ai/GOT-OCR2_0', trust_remote_code=True)

processor = TrOCRProcessor.from_pretrained('microsoft/trocr-base-handwritten')
model = VisionEncoderDecoderModel.from_pretrained('microsoft/trocr-base-handwritten')


image_path = '/content/8.jpg'
image = Image.open(image_path).convert("RGB")

pixel_values = processor(images=image, return_tensors="pt").pixel_values

model_path = 'yolo_model.pt'

arabic_characters = set("٠١٢٣٤٥٦٧٨٩")
english_characters = set("0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ")

def translate_text(text):
    if text in a2eL:
        return a2eL[text]
    elif text in a2eN:
        return a2eN[text]

    return text
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-handwritten and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

generated_text
# Out:
# '2549 to'

# %%
def add_padding(cropped_img, padding=10):
    h, w, _ = cropped_img.shape
    padded_img = cv2.copyMakeBorder(cropped_img, padding, padding, padding, padding, cv2.BORDER_CONSTANT, value=[255, 255, 255])
    return padded_img

# Function to filter and clean the predicted text, ensuring it only contains a valid character
def filter_text(text):
    # Filter Arabic characters
    arabic_text = ''.join([char for char in text if char in arabic_characters])

    # Filter English characters
    english_text = ''.join([char for char in text if char in english_characters])

    # If both are found, prioritize the selection (modify as per your preference)
    if arabic_text:
        return arabic_text[0]  # Return the first Arabic character
    elif english_text:
        return english_text[0]  # Return the first English character

    # If no valid character is found, return an empty string
    return ""

# Function to perform OCR on the lower half of each bounding box and return a single character (Arabic or English)
def ocr_on_bounding_box(image, bbox, idx, margin=5):
    # Extract bounding box coordinates
    x_min, y_min, x_max, y_max = map(int, bbox[:4])

    # Increase the bounding box size by the margin, making sure not to exceed the image boundaries
    x_min = max(0, x_min - margin)
    y_min = max(0, y_min - margin)
    x_max = min(image.shape[1], x_max + margin)
    y_max = min(image.shape[0], y_max + margin)

    # Compute the middle point of the bounding box height
    middle_y = (y_min + y_max) // 2

    # Crop only the lower half of the bounding box
    lower_half_img = image[middle_y:y_max, x_min:x_max]

    # Add padding to the cropped image if needed
    padded_img = add_padding(lower_half_img)

    # Save the padded cropped image temporarily
    cropped_img_path = f"cropped_{idx}.jpg"
    cv2.imwrite(cropped_img_path, padded_img)

    # Perform OCR detection using the transformer model
    res = model.chat(tokenizer, cropped_img_path, ocr_type='ocr')

    # Remove the temporary cropped image
    os.remove(cropped_img_path)

    # Filter the result to ensure it only contains one valid character (either Arabic or English)
    best_text = filter_text(res)

    return best_text, lower_half_img

# Function to use YOLO for bounding box detection, crop images, and apply the transformer OCR model
def detect_and_ocr(image_path, model_path):
    # Load the YOLO model
    yolo_model = YOLO(model_path)

    # Load the image
    image = cv2.imread(image_path)

    # Perform YOLO prediction on the image
    results = yolo_model.predict(source=image, conf=0.01)

    # Extract bounding boxes from YOLO predictions (results[0].boxes.data gives you the bbox data)
    bounding_boxes = results[0].boxes.data.cpu().numpy()  # Convert tensor to numpy array

    # Sort bounding boxes from left to right based on the x_min value (the leftmost point)
    bounding_boxes = sorted(bounding_boxes, key=lambda x: x[0])  # Sort by x_min (x[0])

    # Initialize an empty string to store the final license plate prediction
    license_plate_prediction = ''

    # Loop through each bounding box (sorted) and apply OCR
    for idx, bbox in enumerate(bounding_boxes):
        # Perform OCR on the lower half of the cropped image from the bounding box, with expanded margin
        predicted_text, cropped_img = ocr_on_bounding_box(image, bbox, idx, margin=5)  # Margin is 5 pixels

        # Add the predicted text to the final license plate prediction
        license_plate_prediction += predicted_text

        # Draw bounding box on the original image
        x_min, y_min, x_max, y_max = map(int, bbox[:4])
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        cv2.putText(image, predicted_text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        # Show each cropped image separately
        plt.figure(figsize=(3, 3))
        plt.imshow(cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB))
        plt.title(f'Cropped Lower Half Image: {predicted_text}')
        plt.axis('off')
        plt.show()

    # Show the original image with bounding boxes
    plt.figure(figsize=(10, 5))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title("Image with Bounding Boxes and Predictions")
    plt.axis('off')
    plt.show()

    # Return the final license plate prediction
    return license_plate_prediction




# Run the detection and OCR pipeline
license_plate_prediction = detect_and_ocr(image_path, model_path)

# Print the final license plate prediction
print("License Plate Prediction:", license_plate_prediction)
# Out:
# 0: 416x640 1 09, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 6.9ms postprocess per image at shape (1, 3, 416, 640)
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# License Plate Prediction: 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr

model_path = 'yolo_model.pt'
model = YOLO(model_path)

image_path = '/content/Dataset/License-Characters-by-2-27classes/train/ckictw05s0001246aeel6cew4.jpeg'
image = cv2.imread(image_path)

H, W = image.shape[:2]

results = model.predict(image, conf=0.01)
# Out:
# 0: 352x640 2 02s, 1 03, 1 05, 1 11, 1 12, 1 18, 37.2ms
# Speed: 1.4ms preprocess, 37.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)

# %%
# Get the bounding boxes (results[0].boxes.data gives you the bbox data)
bounding_boxes = results[0].boxes.data.cpu().numpy()

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'])  # You can add other languages if needed

# Function to perform OCR on each bounding box
def ocr_on_bounding_box(image, bbox):
    x_min, y_min, x_max, y_max, confidence, _ = bbox

    # Convert float values to integers for cropping the image
    x_min, y_min, x_max, y_max = int(x_min), int(y_min), int(x_max), int(y_max)

    # Crop the image based on the bounding box
    cropped_img = image[y_min:y_max, x_min:x_max]

    # Use EasyOCR to detect text in the cropped region
    ocr_results = reader.readtext(cropped_img)

    # Get the best result based on confidence
    if ocr_results:
        highest_confidence = max(ocr_results, key=lambda res: res[2])
        text, confidence = highest_confidence[1], highest_confidence[2]
        return text, confidence
    else:
        return '', 0
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# Initialize an empty string to store the final license plate prediction
license_plate_prediction = ''

# Draw bounding boxes and perform OCR for each box
for bbox in bounding_boxes:
    x_min, y_min, x_max, y_max, confidence, class_id = bbox.astype(int)

    # Perform OCR on each bounding box
    character, char_confidence = ocr_on_bounding_box(image, bbox)

    # Add the character to the final license plate prediction
    if char_confidence > 0:  # Adjust confidence threshold as needed
        license_plate_prediction += character

    # Draw the bounding box on the image (for visualization)
    # cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
    # cv2.putText(image, character, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# Show the image with bounding boxes
plt.figure(figsize=(10, 5))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# Print the final license plate prediction
print("License Plate Prediction:", license_plate_prediction)
# Out:
# License Plate Prediction: B35

# %%
# !pip install tiktoken verovio

# !pip install verovio
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting verovio
#   Downloading verovio-4.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.2 MB/s eta 0:00:00
# Downloading verovio-4.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 50.6 MB/s eta 0:00:00
# Installing collected packages: verovio, tiktoken
# Successfully installed tiktoken-0.7.0 verovio-4.3.1

# %%
# !pip install paddlepaddle paddleocr paddlepaddle-gpu
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting paddlepaddle-gpu
#   Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting httpx (from paddlepaddle)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (4.4.2)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.24.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.3.0.post5)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.35.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 8.4 MB/s eta 0:00:00
# Downloading paddleocr-2.8.1-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 27.2 MB/s eta 0:00:00
# Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl (758.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 826.3 kB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 20.5 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 19.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 57.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=5c1f8815c3cf1e257fdb4ef574e842ef61abd21adad076c891380ba3fd1cc193
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: lmdb, rapidfuzz, python-docx, h11, fire, astor, httpcore, httpx, paddlepaddle-gpu, paddlepaddle, paddleocr
# Successfully installed astor-0.8.1 fire-0.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 lmdb-1.5.1 paddleocr-2.8.1 paddlepaddle-2.6.2 paddlepaddle-gpu-2.6.2 python-docx-1.1.2 rapidfuzz-3.10.0

# %%
from paddleocr import PaddleOCR, draw_ocr
import cv2
import matplotlib.pyplot as plt

# Initialize the PaddleOCR model (Enable the correct language model: Arabic or English)
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Use 'en' for English and 'ar' for Arabic

# Path to the license plate image
image_path = '/content/8.jpg'

# Read the image using OpenCV
image = cv2.imread(image_path)

# Perform OCR detection on the image
ocr_results = ocr.ocr(image_path)

# Extract the OCR results (bounding boxes and recognized text)
for line in ocr_results:
    for text_info in line:
        text = text_info[1][0]  # The recognized text
        confidence = text_info[1][1]  # Confidence score
        print(f"Detected text: {text} (Confidence: {confidence})")

# Visualize the results by drawing bounding boxes and recognized text on the image
# Convert the OpenCV image to RGB (for visualization)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Extract the boxes and texts from the results
boxes = [item[0] for item in ocr_results[0]]
texts = [item[1][0] for item in ocr_results[0]]
scores = [item[1][1] for item in ocr_results[0]]

# Draw the results on the image
# image_with_boxes = draw_ocr(image_rgb, boxes, texts, scores, font_path='path_to_font')  # Optional: provide a font path if needed

# Convert back to OpenCV format for visualization with matplotlib
image_with_boxes = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

# Display the image with bounding boxes
plt.figure(figsize=(10, 10))
plt.imshow(image_with_boxes)
plt.axis('off')
plt.show()
# Out:
# [2024/09/30 14:33:57] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/09/30 14:34:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.030549287796020508
# [2024/09/30 14:34:01] ppocr DEBUG: cls num  : 2, elapsed : 0.023888349533081055
# [2024/09/30 14:34:01] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11081218719482422
# Detected text: 2r11e (Confidence: 0.5588568449020386)
# Detected text: 4319EGJ (Confidence: 0.7967853546142578)

# %%
import random
import string
import math
import itertools
import os

import numpy as np
import pandas as pd
import imgaug
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn.model_selection
import imgaug.augmenters as iaa

from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models

import xml.etree.ElementTree as ET

import cv2

# %%
# Define the directory where the XML files and images are stored
xml_dir = '/content/Dataset/License-Characters-by-2-27classes/train'  # Update with the correct path
image_dir = '/content/Dataset/License-Characters-by-2-27classes/train'  # Update with the correct path

def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    filename = root.find('filename').text

    labels = []
    for obj in root.findall('object'):
        label = obj.find('name').text
        labels.append(label)

    return filename, labels

def has_three_alphabets(labels):
    alphabet_count = sum([1 for label in labels if label.isalpha()])
    return alphabet_count == 3

image_labels = []
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith('.xml'):
        xml_file_path = os.path.join(xml_dir, xml_filename)

        image_filename, labels = parse_xml(xml_file_path)

        if has_three_alphabets(labels):
            image_path = os.path.join(image_dir, image_filename)
            image_labels.append((image_path, labels))

# %%
image_paths = []
labels = []

for path,label in image_labels:
  image_paths.append(path)
  labels.append(label)

# %%
labels_test = [''.join(i) for i in labels]

# %%
labels = labels_test

# %%
# Out:
#   File "<ipython-input-100-f80a7ebc0a67>", line 1
#     PaddleOCR()?
#                ^
# SyntaxError: invalid syntax

# %%
from paddleocr import PaddleOCR
from sklearn.metrics import accuracy_score

# Initialize PaddleOCR (for English or Arabic as needed)
ocr = PaddleOCR(use_angle_cls=True, lang='en', ocr_version='PP-OCRv4', use_space_char=True)

def get_ocr_result(image_path):
    # Perform OCR on the image
    ocr_results = ocr.ocr(image_path,det=True,cls=False,rec=True)

    # If the result is None or empty, return an empty string
    if ocr_results is None or len(ocr_results) == 0:
        return ""

    # Collect all texts and confidence scores from OCR
    most_confident_text = ""
    highest_confidence = 0

    # Iterate through the results (Ensure it is iterable)
    for line in ocr_results:
        if line is not None:  # Check if the line itself is not None
            for text_info in line:
                if text_info and isinstance(text_info, list) and len(text_info) > 1:
                    text = text_info[1][0]  # Extract recognized text
                    confidence = text_info[1][1]  # Extract confidence score
                    # Keep the most confident text
                    if confidence > highest_confidence:
                        highest_confidence = confidence
                        most_confident_text = text

    return most_confident_text

# Function to compute accuracy between OCR results and ground truth labels
def evaluate_ocr(image_paths, labels):
    predicted_texts = []
    for image_path in image_paths:
        # Get the most confident text for each image
        ocr_text = get_ocr_result(image_path)
        predicted_texts.append(ocr_text)

    # Calculate the accuracy score between the predicted texts and ground truth labels
    accuracies = [1 if predicted == label else 0 for predicted, label in zip(predicted_texts, labels)]
    overall_accuracy = sum(accuracies) / len(accuracies)

    # Optionally, return more detailed comparison results
    return overall_accuracy, predicted_texts

# Example usage:


# Run evaluation
overall_accuracy, predicted_texts = evaluate_ocr(image_paths, labels)

# Output the results
print(f"Overall Accuracy: {overall_accuracy * 100:.2f}%")
for i, (image, prediction, label) in enumerate(zip(image_paths, predicted_texts, labels)):
    print(f"Image {i+1}: {image}")
    print(f"Predicted: {prediction}, Ground Truth: {label}")
# Out:
# [2024/09/30 15:38:11] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/09/30 15:38:14] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.09138941764831543
# [2024/09/30 15:38:15] ppocr DEBUG: rec_res num  : 5, elapsed : 0.35683655738830566
# [2024/09/30 15:38:15] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.06789207458496094
# [2024/09/30 15:38:15] ppocr DEBUG: rec_res num  : 1, elapsed : 0.08139300346374512
# [2024/09/30 15:38:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09214091300964355
# [2024/09/30 15:38:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16044139862060547
# [2024/09/30 15:38:15] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.374157190322876
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1901845932006836
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.039466142654418945
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09791207313537598
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02729344367980957
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10233497619628906
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.17981219291687012
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 5, elapsed : 0.15703344345092773
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01859879493713379
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.07539558410644531
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01790165901184082
# [2024/09/30 15:38:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.07495760917663574
# [2024/09/30 15:38:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.016889333724975586
# [2024/09/30 15:38:17] ppocr DEBUG: rec_res num  : 2, elapsed : 0.07684969902038574
# [2024/09/30 15:38:17] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.09544253349304199
# [2024/09/30 15:38:17] ppocr DEBUG: rec_res num  : 6, elapsed : 0.38318705558776855
# [2024/09/30 15:38:17] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.03837299346923828
# [2024/09/30 15:38:17] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21040940284729004
# [2024/09/30 15:38:17] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.03475356101989746
# [2024/09/30 15:38:18] ppocr DEBUG: rec_res num  : 6, elapsed : 0.20805859565734863
# [2024/09/30 15:38:18] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12799453735351562
# [2024/09/30 15:38:18] ppocr DEBUG: rec_res num  : 4, elapsed : 0.19294285774230957
# [2024/09/30 15:38:18] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.29938745498657227
# [2024/09/30 15:38:18] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1605668067932129
# [2024/09/30 15:38:18] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.09911608695983887
# [2024/09/30 15:38:19] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3034019470214844
# [2024/09/30 15:38:19] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.017848491668701172
# [2024/09/30 15:38:19] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09056448936462402
# [2024/09/30 15:38:19] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.32547497749328613
# [2024/09/30 15:38:19] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12550663948059082
# [2024/09/30 15:38:19] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01872086524963379
# [2024/09/30 15:38:19] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08828020095825195
# [2024/09/30 15:38:19] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0171201229095459
# [2024/09/30 15:38:20] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08603429794311523
# [2024/09/30 15:38:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.07317495346069336
# [2024/09/30 15:38:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0721578598022461
# [2024/09/30 15:38:20] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.0851445198059082
# [2024/09/30 15:38:20] ppocr DEBUG: rec_res num  : 7, elapsed : 0.28681135177612305
# [2024/09/30 15:38:20] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.1118459701538086
# [2024/09/30 15:38:21] ppocr DEBUG: rec_res num  : 8, elapsed : 0.33619022369384766
# [2024/09/30 15:38:21] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.04175138473510742
# [2024/09/30 15:38:21] ppocr DEBUG: rec_res num  : 5, elapsed : 0.19560456275939941
# [2024/09/30 15:38:21] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.059189558029174805
# [2024/09/30 15:38:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05993056297302246
# [2024/09/30 15:38:21] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.11636066436767578
# [2024/09/30 15:38:21] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16557621955871582
# [2024/09/30 15:38:21] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03890633583068848
# [2024/09/30 15:38:21] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09232425689697266
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.18168234825134277
# [2024/09/30 15:38:22] ppocr DEBUG: rec_res num  : 5, elapsed : 0.18943071365356445
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.017101526260375977
# [2024/09/30 15:38:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09421753883361816
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.020250797271728516
# [2024/09/30 15:38:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09592556953430176
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.03692030906677246
# [2024/09/30 15:38:22] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1788334846496582
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03750443458557129
# [2024/09/30 15:38:22] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:38:22] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.07573676109313965
# [2024/09/30 15:38:23] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17277312278747559
# [2024/09/30 15:38:23] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.29204893112182617
# [2024/09/30 15:38:23] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3330078125
# [2024/09/30 15:38:23] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.23296046257019043
# [2024/09/30 15:38:24] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12010693550109863
# [2024/09/30 15:38:24] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.07342028617858887
# [2024/09/30 15:38:24] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:38:24] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.14876341819763184
# [2024/09/30 15:38:24] ppocr DEBUG: rec_res num  : 16, elapsed : 0.7276017665863037
# [2024/09/30 15:38:25] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.15171003341674805
# [2024/09/30 15:38:25] ppocr DEBUG: rec_res num  : 3, elapsed : 0.2073678970336914
# [2024/09/30 15:38:25] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.17232179641723633
# [2024/09/30 15:38:25] ppocr DEBUG: rec_res num  : 5, elapsed : 0.23291802406311035
# [2024/09/30 15:38:25] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12296080589294434
# [2024/09/30 15:38:26] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1834266185760498
# [2024/09/30 15:38:26] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.35212087631225586
# [2024/09/30 15:38:26] ppocr DEBUG: rec_res num  : 3, elapsed : 0.15670251846313477
# [2024/09/30 15:38:26] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.24186491966247559
# [2024/09/30 15:38:27] ppocr DEBUG: rec_res num  : 5, elapsed : 0.22061562538146973
# [2024/09/30 15:38:27] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.21129560470581055
# [2024/09/30 15:38:27] ppocr DEBUG: rec_res num  : 4, elapsed : 0.20098304748535156
# [2024/09/30 15:38:27] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.08917760848999023
# [2024/09/30 15:38:27] ppocr DEBUG: rec_res num  : 2, elapsed : 0.17635464668273926
# [2024/09/30 15:38:27] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.055375099182128906
# [2024/09/30 15:38:27] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09753537178039551
# [2024/09/30 15:38:28] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.050208330154418945
# [2024/09/30 15:38:28] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# [2024/09/30 15:38:28] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.18358707427978516
# [2024/09/30 15:38:28] ppocr DEBUG: rec_res num  : 7, elapsed : 0.33080363273620605
# [2024/09/30 15:38:28] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023155927658081055
# [2024/09/30 15:38:28] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09048056602478027
# [2024/09/30 15:38:28] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022392749786376953
# [2024/09/30 15:38:28] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0924828052520752
# [2024/09/30 15:38:28] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.16699767112731934
# [2024/09/30 15:38:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09806036949157715
# [2024/09/30 15:38:29] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08701515197753906
# [2024/09/30 15:38:29] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21733689308166504
# [2024/09/30 15:38:29] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.185197114944458
# [2024/09/30 15:38:29] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15154504776000977
# [2024/09/30 15:38:29] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.030191659927368164
# [2024/09/30 15:38:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09682178497314453
# [2024/09/30 15:38:29] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0373990535736084
# [2024/09/30 15:38:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09781289100646973
# [2024/09/30 15:38:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.09129571914672852
# [2024/09/30 15:38:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.20915651321411133
# [2024/09/30 15:38:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.20545029640197754
# [2024/09/30 15:38:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17420005798339844
# [2024/09/30 15:38:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.06653094291687012
# [2024/09/30 15:38:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.25123167037963867
# [2024/09/30 15:38:31] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.055527448654174805
# [2024/09/30 15:38:31] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10070586204528809
# [2024/09/30 15:38:31] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.1241464614868164
# [2024/09/30 15:38:31] ppocr DEBUG: rec_res num  : 6, elapsed : 0.26089906692504883
# [2024/09/30 15:38:31] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02257513999938965
# [2024/09/30 15:38:31] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09109234809875488
# [2024/09/30 15:38:31] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.021842002868652344
# [2024/09/30 15:38:31] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09488868713378906
# [2024/09/30 15:38:31] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0722801685333252
# [2024/09/30 15:38:31] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09416604042053223
# [2024/09/30 15:38:32] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.11008119583129883
# [2024/09/30 15:38:32] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2249164581298828
# [2024/09/30 15:38:32] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.13311338424682617
# [2024/09/30 15:38:32] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3136863708496094
# [2024/09/30 15:38:32] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06435012817382812
# [2024/09/30 15:38:32] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# [2024/09/30 15:38:32] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.07878994941711426
# [2024/09/30 15:38:33] ppocr DEBUG: rec_res num  : 5, elapsed : 0.20773863792419434
# [2024/09/30 15:38:33] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05508160591125488
# [2024/09/30 15:38:33] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09350442886352539
# [2024/09/30 15:38:33] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10014104843139648
# [2024/09/30 15:38:33] ppocr DEBUG: rec_res num  : 5, elapsed : 0.16865801811218262
# [2024/09/30 15:38:33] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.10658860206604004
# [2024/09/30 15:38:34] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4102358818054199
# [2024/09/30 15:38:34] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10344815254211426
# [2024/09/30 15:38:34] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17457175254821777
# [2024/09/30 15:38:34] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.179473876953125
# [2024/09/30 15:38:34] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16231942176818848
# [2024/09/30 15:38:34] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2498011589050293
# [2024/09/30 15:38:35] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1895277500152588
# [2024/09/30 15:38:35] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.07683300971984863
# [2024/09/30 15:38:35] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21895551681518555
# [2024/09/30 15:38:35] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.14881229400634766
# [2024/09/30 15:38:35] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17347478866577148
# [2024/09/30 15:38:35] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06212425231933594
# [2024/09/30 15:38:36] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14290308952331543
# [2024/09/30 15:38:36] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.05516815185546875
# [2024/09/30 15:38:36] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11954784393310547
# [2024/09/30 15:38:36] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.061714887619018555
# [2024/09/30 15:38:36] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09541487693786621
# [2024/09/30 15:38:36] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.23738646507263184
# [2024/09/30 15:38:36] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17573952674865723
# [2024/09/30 15:38:36] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.035565853118896484
# [2024/09/30 15:38:37] ppocr DEBUG: rec_res num  : 6, elapsed : 0.22258234024047852
# [2024/09/30 15:38:37] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.2431488037109375
# [2024/09/30 15:38:37] ppocr DEBUG: rec_res num  : 4, elapsed : 0.20689892768859863
# [2024/09/30 15:38:37] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.12763166427612305
# [2024/09/30 15:38:37] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16855406761169434
# [2024/09/30 15:38:37] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.11015033721923828
# [2024/09/30 15:38:38] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2642536163330078
# [2024/09/30 15:38:38] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.18048954010009766
# [2024/09/30 15:38:38] ppocr DEBUG: rec_res num  : 5, elapsed : 0.2035045623779297
# [2024/09/30 15:38:38] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.05560302734375
# [2024/09/30 15:38:38] ppocr DEBUG: rec_res num  : 6, elapsed : 0.27718687057495117
# [2024/09/30 15:38:39] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09021329879760742
# [2024/09/30 15:38:39] ppocr DEBUG: rec_res num  : 2, elapsed : 0.18474936485290527
# [2024/09/30 15:38:39] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03386950492858887
# [2024/09/30 15:38:39] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11672568321228027
# [2024/09/30 15:38:39] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07764053344726562
# [2024/09/30 15:38:39] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12344026565551758
# [2024/09/30 15:38:39] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2031843662261963
# [2024/09/30 15:38:40] ppocr DEBUG: rec_res num  : 5, elapsed : 0.23577237129211426
# [2024/09/30 15:38:40] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03244805335998535
# [2024/09/30 15:38:40] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13170504570007324
# [2024/09/30 15:38:40] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.11859989166259766
# [2024/09/30 15:38:40] ppocr DEBUG: rec_res num  : 7, elapsed : 0.42590856552124023
# [2024/09/30 15:38:40] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.20088887214660645
# [2024/09/30 15:38:41] ppocr DEBUG: rec_res num  : 6, elapsed : 0.27263855934143066
# [2024/09/30 15:38:41] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.050169944763183594
# [2024/09/30 15:38:41] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2643702030181885
# [2024/09/30 15:38:41] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03173518180847168
# [2024/09/30 15:38:41] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1204679012298584
# [2024/09/30 15:38:41] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.09346985816955566
# [2024/09/30 15:38:41] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:38:41] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.10700583457946777
# [2024/09/30 15:38:42] ppocr DEBUG: rec_res num  : 7, elapsed : 0.33777618408203125
# [2024/09/30 15:38:42] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02968311309814453
# [2024/09/30 15:38:42] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09283709526062012
# [2024/09/30 15:38:42] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.09832310676574707
# [2024/09/30 15:38:42] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16510868072509766
# [2024/09/30 15:38:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06913042068481445
# [2024/09/30 15:38:42] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# [2024/09/30 15:38:42] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.13725852966308594
# [2024/09/30 15:38:43] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1989881992340088
# [2024/09/30 15:38:43] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.12028360366821289
# [2024/09/30 15:38:43] ppocr DEBUG: rec_res num  : 6, elapsed : 0.22931480407714844
# [2024/09/30 15:38:43] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023158788681030273
# [2024/09/30 15:38:43] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09745049476623535
# [2024/09/30 15:38:43] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.21300387382507324
# [2024/09/30 15:38:43] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12877631187438965
# [2024/09/30 15:38:44] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.0981283187866211
# [2024/09/30 15:38:44] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21585869789123535
# [2024/09/30 15:38:44] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08945894241333008
# [2024/09/30 15:38:44] ppocr DEBUG: rec_res num  : 6, elapsed : 0.22931885719299316
# [2024/09/30 15:38:44] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.07629275321960449
# [2024/09/30 15:38:44] ppocr DEBUG: rec_res num  : 6, elapsed : 0.20445036888122559
# [2024/09/30 15:38:44] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02340555191040039
# [2024/09/30 15:38:45] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08922433853149414
# [2024/09/30 15:38:45] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.10816597938537598
# [2024/09/30 15:38:45] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21851849555969238
# [2024/09/30 15:38:45] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.13392114639282227
# [2024/09/30 15:38:45] ppocr DEBUG: rec_res num  : 3, elapsed : 0.13172602653503418
# [2024/09/30 15:38:45] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.02915501594543457
# [2024/09/30 15:38:45] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21089839935302734
# [2024/09/30 15:38:45] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.11473822593688965
# [2024/09/30 15:38:46] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1943976879119873
# [2024/09/30 15:38:46] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.06766748428344727
# [2024/09/30 15:38:46] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10481643676757812
# [2024/09/30 15:38:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06196451187133789
# [2024/09/30 15:38:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13414216041564941
# [2024/09/30 15:38:46] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08495497703552246
# [2024/09/30 15:38:46] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21469521522521973
# [2024/09/30 15:38:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023815155029296875
# [2024/09/30 15:38:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0899202823638916
# [2024/09/30 15:38:47] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07797813415527344
# [2024/09/30 15:38:47] ppocr DEBUG: rec_res num  : 4, elapsed : 0.19971799850463867
# [2024/09/30 15:38:47] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.024151325225830078
# [2024/09/30 15:38:47] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09279108047485352
# [2024/09/30 15:38:47] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0708169937133789
# [2024/09/30 15:38:47] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08711981773376465
# [2024/09/30 15:38:47] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.12321972846984863
# [2024/09/30 15:38:47] ppocr DEBUG: rec_res num  : 7, elapsed : 0.27476978302001953
# [2024/09/30 15:38:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02492666244506836
# [2024/09/30 15:38:48] ppocr DEBUG: rec_res num  : 1, elapsed : 0.062341928482055664
# [2024/09/30 15:38:48] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.13195323944091797
# [2024/09/30 15:38:48] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21413016319274902
# [2024/09/30 15:38:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023289203643798828
# [2024/09/30 15:38:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09761238098144531
# [2024/09/30 15:38:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.024017333984375
# [2024/09/30 15:38:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09674882888793945
# [2024/09/30 15:38:48] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1294102668762207
# [2024/09/30 15:38:48] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16379475593566895
# [2024/09/30 15:38:49] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.05826592445373535
# [2024/09/30 15:38:49] ppocr DEBUG: rec_res num  : 1, elapsed : 0.06447196006774902
# [2024/09/30 15:38:49] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12096452713012695
# [2024/09/30 15:38:49] ppocr DEBUG: rec_res num  : 4, elapsed : 0.19701910018920898
# [2024/09/30 15:38:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05875396728515625
# [2024/09/30 15:38:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09268307685852051
# [2024/09/30 15:38:49] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.2216782569885254
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2544536590576172
# [2024/09/30 15:38:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06344485282897949
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:38:50] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06310868263244629
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0916597843170166
# [2024/09/30 15:38:50] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07477855682373047
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1577436923980713
# [2024/09/30 15:38:50] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05903506278991699
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09302687644958496
# [2024/09/30 15:38:50] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.07900762557983398
# [2024/09/30 15:38:50] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16460204124450684
# [2024/09/30 15:38:51] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.07409405708312988
# [2024/09/30 15:38:51] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3234095573425293
# [2024/09/30 15:38:51] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.021701574325561523
# [2024/09/30 15:38:51] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0941915512084961
# [2024/09/30 15:38:51] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.13114333152770996
# [2024/09/30 15:38:51] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15158820152282715
# [2024/09/30 15:38:51] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.12333250045776367
# [2024/09/30 15:38:52] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1953411102294922
# [2024/09/30 15:38:52] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.11629080772399902
# [2024/09/30 15:38:52] ppocr DEBUG: rec_res num  : 5, elapsed : 0.21907925605773926
# [2024/09/30 15:38:52] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14762330055236816
# [2024/09/30 15:38:52] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11624360084533691
# [2024/09/30 15:38:52] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.07429242134094238
# [2024/09/30 15:38:52] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:38:52] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.037880897521972656
# [2024/09/30 15:38:52] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10796856880187988
# [2024/09/30 15:38:53] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.09653043746948242
# [2024/09/30 15:38:53] ppocr DEBUG: rec_res num  : 5, elapsed : 0.2133655548095703
# [2024/09/30 15:38:53] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.4570021629333496
# [2024/09/30 15:38:54] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6263799667358398
# [2024/09/30 15:38:54] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.21533465385437012
# [2024/09/30 15:38:54] ppocr DEBUG: rec_res num  : 4, elapsed : 0.24716544151306152
# [2024/09/30 15:38:54] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.032082557678222656
# [2024/09/30 15:38:55] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1475536823272705
# [2024/09/30 15:38:55] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.13785123825073242
# [2024/09/30 15:38:55] ppocr DEBUG: rec_res num  : 8, elapsed : 0.4626762866973877
# [2024/09/30 15:38:55] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.18054676055908203
# [2024/09/30 15:38:56] ppocr DEBUG: rec_res num  : 4, elapsed : 0.19676899909973145
# [2024/09/30 15:38:56] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.20695161819458008
# [2024/09/30 15:38:56] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15349245071411133
# [2024/09/30 15:38:56] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023150920867919922
# [2024/09/30 15:38:56] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1317439079284668
# [2024/09/30 15:38:56] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.10081267356872559
# [2024/09/30 15:38:56] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21366381645202637
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.17276692390441895
# [2024/09/30 15:38:57] ppocr DEBUG: rec_res num  : 5, elapsed : 0.19433307647705078
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06435823440551758
# [2024/09/30 15:38:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09532499313354492
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022336244583129883
# [2024/09/30 15:38:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08889555931091309
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07543015480041504
# [2024/09/30 15:38:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0934298038482666
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02459120750427246
# [2024/09/30 15:38:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08970093727111816
# [2024/09/30 15:38:57] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.1174612045288086
# [2024/09/30 15:38:58] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1651461124420166
# [2024/09/30 15:38:58] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02597498893737793
# [2024/09/30 15:38:58] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09819817543029785
# [2024/09/30 15:38:58] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.10517525672912598
# [2024/09/30 15:38:58] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3111732006072998
# [2024/09/30 15:38:58] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.09539961814880371
# [2024/09/30 15:38:59] ppocr DEBUG: rec_res num  : 12, elapsed : 0.4205958843231201
# [2024/09/30 15:38:59] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.024006128311157227
# [2024/09/30 15:38:59] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08982682228088379
# [2024/09/30 15:38:59] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.19198846817016602
# [2024/09/30 15:38:59] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15196728706359863
# [2024/09/30 15:38:59] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02481842041015625
# [2024/09/30 15:38:59] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09235358238220215
# [2024/09/30 15:38:59] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14958882331848145
# [2024/09/30 15:39:00] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09582352638244629
# [2024/09/30 15:39:00] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.12665057182312012
# [2024/09/30 15:39:00] ppocr DEBUG: rec_res num  : 5, elapsed : 0.19063830375671387
# [2024/09/30 15:39:00] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.07607173919677734
# [2024/09/30 15:39:00] ppocr DEBUG: rec_res num  : 7, elapsed : 0.2947516441345215
# [2024/09/30 15:39:00] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.028345584869384766
# [2024/09/30 15:39:00] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09350466728210449
# [2024/09/30 15:39:01] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12192773818969727
# [2024/09/30 15:39:01] ppocr DEBUG: rec_res num  : 4, elapsed : 0.17325067520141602
# [2024/09/30 15:39:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.1255474090576172
# [2024/09/30 15:39:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17832684516906738
# [2024/09/30 15:39:01] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.20634126663208008
# [2024/09/30 15:39:01] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16312813758850098
# [2024/09/30 15:39:01] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.08414196968078613
# [2024/09/30 15:39:02] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12881803512573242
# [2024/09/30 15:39:02] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08232665061950684
# [2024/09/30 15:39:02] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2605016231536865
# [2024/09/30 15:39:02] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06824898719787598
# [2024/09/30 15:39:02] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09425711631774902
# [2024/09/30 15:39:02] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.09659385681152344
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 8, elapsed : 0.30317187309265137
# [2024/09/30 15:39:03] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0705716609954834
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09380316734313965
# [2024/09/30 15:39:03] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.030162572860717773
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09509897232055664
# [2024/09/30 15:39:03] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07559704780578613
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09218621253967285
# [2024/09/30 15:39:03] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.15365004539489746
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 5, elapsed : 0.18924546241760254
# [2024/09/30 15:39:03] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023569822311401367
# [2024/09/30 15:39:03] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09004640579223633
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.10246729850769043
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12573695182800293
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022426128387451172
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10266590118408203
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06137967109680176
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022618770599365234
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09388256072998047
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0445704460144043
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08160901069641113
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.037358999252319336
# [2024/09/30 15:39:04] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1768639087677002
# [2024/09/30 15:39:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05372214317321777
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08907651901245117
# [2024/09/30 15:39:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.025517940521240234
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10657954216003418
# [2024/09/30 15:39:05] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12003064155578613
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2043747901916504
# [2024/09/30 15:39:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023651599884033203
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10218930244445801
# [2024/09/30 15:39:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0717766284942627
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10295462608337402
# [2024/09/30 15:39:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06775641441345215
# [2024/09/30 15:39:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09539151191711426
# [2024/09/30 15:39:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022773265838623047
# [2024/09/30 15:39:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09759306907653809
# [2024/09/30 15:39:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03326082229614258
# [2024/09/30 15:39:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11423659324645996
# [2024/09/30 15:39:06] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.2201852798461914
# [2024/09/30 15:39:06] ppocr DEBUG: rec_res num  : 7, elapsed : 0.43440937995910645
# [2024/09/30 15:39:07] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.16045403480529785
# [2024/09/30 15:39:07] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2613348960876465
# [2024/09/30 15:39:07] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.19105982780456543
# [2024/09/30 15:39:07] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3384251594543457
# [2024/09/30 15:39:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06912922859191895
# [2024/09/30 15:39:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12044215202331543
# [2024/09/30 15:39:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03243088722229004
# [2024/09/30 15:39:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12061214447021484
# [2024/09/30 15:39:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.028811931610107422
# [2024/09/30 15:39:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12243223190307617
# [2024/09/30 15:39:08] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.07466816902160645
# [2024/09/30 15:39:08] ppocr DEBUG: rec_res num  : 5, elapsed : 0.23087716102600098
# [2024/09/30 15:39:08] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.21231627464294434
# [2024/09/30 15:39:09] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2593996524810791
# [2024/09/30 15:39:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09354019165039062
# [2024/09/30 15:39:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11670184135437012
# [2024/09/30 15:39:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03141498565673828
# [2024/09/30 15:39:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11981034278869629
# [2024/09/30 15:39:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.052472829818725586
# [2024/09/30 15:39:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1094350814819336
# [2024/09/30 15:39:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.029962778091430664
# [2024/09/30 15:39:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11365056037902832
# [2024/09/30 15:39:09] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03043508529663086
# [2024/09/30 15:39:10] ppocr DEBUG: rec_res num  : 1, elapsed : 0.07740044593811035
# [2024/09/30 15:39:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.031219482421875
# [2024/09/30 15:39:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12605714797973633
# [2024/09/30 15:39:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.034645795822143555
# [2024/09/30 15:39:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1251692771911621
# [2024/09/30 15:39:10] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.10084724426269531
# [2024/09/30 15:39:10] ppocr DEBUG: rec_res num  : 4, elapsed : 0.21132612228393555
# [2024/09/30 15:39:10] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.2252507209777832
# [2024/09/30 15:39:11] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1729569435119629
# [2024/09/30 15:39:11] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10541772842407227
# [2024/09/30 15:39:11] ppocr DEBUG: rec_res num  : 5, elapsed : 0.19712328910827637
# [2024/09/30 15:39:11] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023525238037109375
# [2024/09/30 15:39:11] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0895693302154541
# [2024/09/30 15:39:11] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.11162066459655762
# [2024/09/30 15:39:11] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1599748134613037
# [2024/09/30 15:39:11] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.12809181213378906
# [2024/09/30 15:39:12] ppocr DEBUG: rec_res num  : 5, elapsed : 0.18042922019958496
# [2024/09/30 15:39:12] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.02140641212463379
# [2024/09/30 15:39:12] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# [2024/09/30 15:39:12] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.061695098876953125
# [2024/09/30 15:39:12] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09969449043273926
# [2024/09/30 15:39:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022700786590576172
# [2024/09/30 15:39:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09505820274353027
# [2024/09/30 15:39:12] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.14280962944030762
# [2024/09/30 15:39:12] ppocr DEBUG: rec_res num  : 5, elapsed : 0.179229736328125
# [2024/09/30 15:39:12] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.12918877601623535
# [2024/09/30 15:39:13] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4312255382537842
# [2024/09/30 15:39:13] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.12571024894714355
# [2024/09/30 15:39:13] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17740845680236816
# [2024/09/30 15:39:13] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.1197061538696289
# [2024/09/30 15:39:13] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1494736671447754
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06083488464355469
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06633162498474121
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10277462005615234
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.09826064109802246
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17615842819213867
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02341437339782715
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09185957908630371
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02309870719909668
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1018974781036377
# [2024/09/30 15:39:14] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.10398125648498535
# [2024/09/30 15:39:14] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16262125968933105
# [2024/09/30 15:39:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05683159828186035
# [2024/09/30 15:39:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11040115356445312
# [2024/09/30 15:39:15] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.16196393966674805
# [2024/09/30 15:39:15] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17751622200012207
# [2024/09/30 15:39:15] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.1433117389678955
# [2024/09/30 15:39:16] ppocr DEBUG: rec_res num  : 10, elapsed : 0.45120954513549805
# [2024/09/30 15:39:16] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.06403708457946777
# [2024/09/30 15:39:16] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# [2024/09/30 15:39:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05388903617858887
# [2024/09/30 15:39:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08696770668029785
# [2024/09/30 15:39:16] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.21109676361083984
# [2024/09/30 15:39:16] ppocr DEBUG: rec_res num  : 4, elapsed : 0.14856171607971191
# [2024/09/30 15:39:16] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.20070290565490723
# [2024/09/30 15:39:17] ppocr DEBUG: rec_res num  : 3, elapsed : 0.16064882278442383
# [2024/09/30 15:39:17] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.15276408195495605
# [2024/09/30 15:39:17] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1568002700805664
# [2024/09/30 15:39:17] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06426000595092773
# [2024/09/30 15:39:17] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09260678291320801
# [2024/09/30 15:39:17] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.07943034172058105
# [2024/09/30 15:39:18] ppocr DEBUG: rec_res num  : 7, elapsed : 0.37819504737854004
# [2024/09/30 15:39:18] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.132551908493042
# [2024/09/30 15:39:18] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15422630310058594
# [2024/09/30 15:39:18] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.07261371612548828
# [2024/09/30 15:39:18] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12267804145812988
# [2024/09/30 15:39:18] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.11100554466247559
# [2024/09/30 15:39:18] ppocr DEBUG: rec_res num  : 6, elapsed : 0.22679424285888672
# [2024/09/30 15:39:18] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02265310287475586
# [2024/09/30 15:39:18] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09363174438476562
# [2024/09/30 15:39:18] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023138999938964844
# [2024/09/30 15:39:19] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09294319152832031
# [2024/09/30 15:39:19] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03111863136291504
# [2024/09/30 15:39:19] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09880399703979492
# [2024/09/30 15:39:19] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08191108703613281
# [2024/09/30 15:39:19] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21369171142578125
# [2024/09/30 15:39:19] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.13233685493469238
# [2024/09/30 15:39:19] ppocr DEBUG: rec_res num  : 4, elapsed : 0.15019440650939941
# [2024/09/30 15:39:19] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.03829193115234375
# [2024/09/30 15:39:20] ppocr DEBUG: rec_res num  : 5, elapsed : 0.19597458839416504
# [2024/09/30 15:39:20] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.04850625991821289
# [2024/09/30 15:39:20] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1468822956085205
# [2024/09/30 15:39:20] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.12522649765014648
# [2024/09/30 15:39:20] ppocr DEBUG: rec_res num  : 6, elapsed : 0.23325657844543457
# [2024/09/30 15:39:20] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.10509991645812988
# [2024/09/30 15:39:20] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11816644668579102
# [2024/09/30 15:39:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10228776931762695
# [2024/09/30 15:39:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13320446014404297
# [2024/09/30 15:39:21] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.14559054374694824
# [2024/09/30 15:39:21] ppocr DEBUG: rec_res num  : 8, elapsed : 0.36646294593811035
# [2024/09/30 15:39:21] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.09613966941833496
# [2024/09/30 15:39:21] ppocr DEBUG: rec_res num  : 6, elapsed : 0.25392675399780273
# [2024/09/30 15:39:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09177112579345703
# [2024/09/30 15:39:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13807058334350586
# [2024/09/30 15:39:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04159283638000488
# [2024/09/30 15:39:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11638045310974121
# [2024/09/30 15:39:22] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.19514250755310059
# [2024/09/30 15:39:22] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3548402786254883
# [2024/09/30 15:39:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.029203414916992188
# [2024/09/30 15:39:23] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13728761672973633
# [2024/09/30 15:39:23] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.0641317367553711
# [2024/09/30 15:39:23] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2618887424468994
# [2024/09/30 15:39:23] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0734410285949707
# [2024/09/30 15:39:23] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11648225784301758
# [2024/09/30 15:39:23] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02901768684387207
# [2024/09/30 15:39:23] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11472129821777344
# [2024/09/30 15:39:23] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.05153799057006836
# [2024/09/30 15:39:24] ppocr DEBUG: rec_res num  : 6, elapsed : 0.29507875442504883
# [2024/09/30 15:39:24] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02953338623046875
# [2024/09/30 15:39:24] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11965370178222656
# [2024/09/30 15:39:24] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.16672372817993164
# [2024/09/30 15:39:24] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21871232986450195
# [2024/09/30 15:39:24] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.024486303329467773
# [2024/09/30 15:39:24] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09813046455383301
# [2024/09/30 15:39:24] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.1107017993927002
# [2024/09/30 15:39:25] ppocr DEBUG: rec_res num  : 4, elapsed : 0.16418981552124023
# [2024/09/30 15:39:25] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.025876998901367188
# [2024/09/30 15:39:25] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09657001495361328
# [2024/09/30 15:39:25] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.1853635311126709
# [2024/09/30 15:39:25] ppocr DEBUG: rec_res num  : 5, elapsed : 0.1920619010925293
# [2024/09/30 15:39:25] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.022256135940551758
# [2024/09/30 15:39:25] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09102106094360352
# [2024/09/30 15:39:25] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.0361478328704834
# [2024/09/30 15:39:26] ppocr DEBUG: rec_res num  : 6, elapsed : 0.21397948265075684
# [2024/09/30 15:39:26] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.1384885311126709
# [2024/09/30 15:39:26] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17580246925354004
# [2024/09/30 15:39:26] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.1706373691558838
# [2024/09/30 15:39:26] ppocr DEBUG: rec_res num  : 5, elapsed : 0.17397403717041016
# [2024/09/30 15:39:26] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02336263656616211
# [2024/09/30 15:39:26] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09043312072753906
# [2024/09/30 15:39:26] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06589341163635254
# [2024/09/30 15:39:26] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08914470672607422
# [2024/09/30 15:39:27] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.18713593482971191
# [2024/09/30 15:39:27] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2022228240966797
# [2024/09/30 15:39:27] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.10920166969299316
# [2024/09/30 15:39:27] ppocr DEBUG: rec_res num  : 6, elapsed : 0.20786261558532715
# [2024/09/30 15:39:27] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.11217474937438965
# [2024/09/30 15:39:27] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1512298583984375
# ...
# Predicted: KSA, Ground Truth: 641BBB
# Image 382: /content/Dataset/License-Characters-by-2-27classes/train/ckj702m5b001k246awz9n209g.png
# Predicted: 9315R6, Ground Truth: 9315NRJ
# Image 383: /content/Dataset/License-Characters-by-2-27classes/train/ckie76y86005s246aado5d4mn.jpeg
# Predicted: 9378, Ground Truth: 9378BEJ
# Image 384: /content/Dataset/License-Characters-by-2-27classes/train/ckicyza76001i246ay8xxw8vb.jpeg
# Predicted: 9370, Ground Truth: 9370XKA
# Image 385: /content/Dataset/License-Characters-by-2-27classes/train/ckj6tyl740000246aj140stj4.png
# Predicted: 3735., Ground Truth: 3735TJD
# Image 386: /content/Dataset/License-Characters-by-2-27classes/train/ckie5lqpr004r246afbu6clv0.jpeg
# Predicted: 9717, Ground Truth: 9717BAJ
# Image 387: /content/Dataset/License-Characters-by-2-27classes/train/ckiczrifx0020246ay8apfbfi.jpeg
# Predicted: 8836XNB, Ground Truth: 8836XNB
# Image 388: /content/Dataset/License-Characters-by-2-27classes/train/ckie9bn5v0075246an1yvofgp.jpeg
# Predicted: 6507EGB, Ground Truth: 6507EGB
# Image 389: /content/Dataset/License-Characters-by-2-27classes/train/ckicxnvww000s246aa6qomudl.jpeg
# Predicted: 3047, Ground Truth: 3047JBB
# Image 390: /content/Dataset/License-Characters-by-2-27classes/train/ckj2s1ryr0011246abm9578es.png
# Predicted: BKJ, Ground Truth: 9454BKJ
# Image 391: /content/Dataset/License-Characters-by-2-27classes/train/ckiczfkq2001r246a7irymgr2.png
# Predicted: 9107A00, Ground Truth: 9107AGJ
# Image 392: /content/Dataset/License-Characters-by-2-27classes/train/ckicu9ere0007246agdm9mb4i.jpeg
# Predicted: RUA, Ground Truth: 7403RUA
# Image 393: /content/Dataset/License-Characters-by-2-27classes/train/ckid1q2el003g246afckhsuzf.jpeg
# Predicted: 7873, Ground Truth: 7873ELB
# Image 394: /content/Dataset/License-Characters-by-2-27classes/train/ckicud7x00009246ag1nahatj.jpeg
# Predicted: 4552, Ground Truth: 4552KAA
# Image 395: /content/Dataset/License-Characters-by-2-27classes/train/ckn7cbwkg014s30680jyijnxi.jpeg
# Predicted: 2807zv8, Ground Truth: 2807ZVB
# Image 396: /content/Dataset/License-Characters-by-2-27classes/train/ckj6sm06z001u246an1olss9s.png
# Predicted: 5732NX0, Ground Truth: 5732NXD
# Image 397: /content/Dataset/License-Characters-by-2-27classes/train/ckid1rccj003h246a1p6yi7he.jpeg
# Predicted: 1670ZAJ, Ground Truth: 1670ZAJ
# Image 398: /content/Dataset/License-Characters-by-2-27classes/train/ckj6zg1rf001d246ayi9bgj03.png
# Predicted: 6672BUA, Ground Truth: 6672BAU
# Image 399: /content/Dataset/License-Characters-by-2-27classes/train/ckifkih05008x246as7103oi9.jpeg
# Predicted: 6389BvJ, Ground Truth: 6389BVJ
# Image 400: /content/Dataset/License-Characters-by-2-27classes/train/ckiflc6ct009e246aqrxfkls8.jpeg
# Predicted: 1950SED, Ground Truth: DSE
# Image 401: /content/Dataset/License-Characters-by-2-27classes/train/ckifivbbf007r246ap8iqkizz.jpeg
# Predicted: 7499HSB, Ground Truth: 7499HSB
# Image 402: /content/Dataset/License-Characters-by-2-27classes/train/ckicywqzd001g246afybws3vv.jpeg
# Predicted: 3338, Ground Truth: 3338TNJ
# Image 403: /content/Dataset/License-Characters-by-2-27classes/train/ckid0f9bo002h246apjgcridt.jpeg
# Predicted: 3728, Ground Truth: 3728GKJ
# Image 404: /content/Dataset/License-Characters-by-2-27classes/train/ckid0k377002k246aa82z7ygk.jpeg
# Predicted: , Ground Truth: 5920SAJ
# Image 405: /content/Dataset/License-Characters-by-2-27classes/train/ckie88lrb006i246a0iycvw7m.jpeg
# Predicted: 2264, Ground Truth: 2264JKB
# Image 406: /content/Dataset/License-Characters-by-2-27classes/train/ckicxkxew000r246atma8nywc.jpeg
# Predicted: 6222, Ground Truth: 6222NXD
# Image 407: /content/Dataset/License-Characters-by-2-27classes/train/ckie657f50054246au0cmhbgz.jpeg
# Predicted: 9958, Ground Truth: 9958VXD
# Image 408: /content/Dataset/License-Characters-by-2-27classes/train/ckj2qxj9m0008246ala1hp7zr.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 409: /content/Dataset/License-Characters-by-2-27classes/train/ckie7pj5t0066246adcswvogc.jpeg
# Predicted: 8918, Ground Truth: 8918NLJ
# Image 410: /content/Dataset/License-Characters-by-2-27classes/train/ckicxvbyp000w246a0gvltjb6.jpeg
# Predicted: 4049TJA, Ground Truth: 4049TJA
# Image 411: /content/Dataset/License-Characters-by-2-27classes/train/ckn76ip74007a30682nrx8h01.jpeg
# Predicted: 9760, Ground Truth: 9760RDJ
# Image 412: /content/Dataset/License-Characters-by-2-27classes/train/ckn77ecdm00fu3068vmwodvl4.jpeg
# Predicted: 9116SLB, Ground Truth: 9116SLB
# Image 413: /content/Dataset/License-Characters-by-2-27classes/train/ckicxhg31000p246ay6i8h9zg.jpeg
# Predicted: 3754, Ground Truth: 3754VLJ
# Image 414: /content/Dataset/License-Characters-by-2-27classes/train/ckie66fr50055246a5z432tdp.jpeg
# Predicted: 9116, Ground Truth: 9116SLB
# Image 415: /content/Dataset/License-Characters-by-2-27classes/train/ckn7cvs8i00613h6619wlyc3u.jpeg
# Predicted: 2146EKA, Ground Truth: 2146EKA
# Image 416: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rr2tg000t246atbzvlh1d.png
# Predicted: 3673IND, Ground Truth: 3673TND
# Image 417: /content/Dataset/License-Characters-by-2-27classes/train/ckie62q8z0052246arg65fj6o.jpeg
# Predicted: 2948UR, Ground Truth: 2948URD
# Image 418: /content/Dataset/License-Characters-by-2-27classes/train/ckifkoc1y0092246amgflfxdm.jpeg
# Predicted: 55420VJ, Ground Truth: 5542BVJ
# Image 419: /content/Dataset/License-Characters-by-2-27classes/train/ckie8vc1u006v246a5gqu50ji.jpeg
# Predicted: 5707VAD, Ground Truth: 5707VAD
# Image 420: /content/Dataset/License-Characters-by-2-27classes/train/ckj6v83oy000y246aj4amamko.png
# Predicted: 1541ZKJ, Ground Truth: 1541ZKJ
# Image 421: /content/Dataset/License-Characters-by-2-27classes/train/ckifoipma00ah246a5klmuhp8.jpeg
# Predicted: 1077V0o, Ground Truth: 107VBB
# Image 422: /content/Dataset/License-Characters-by-2-27classes/train/ckj6z33430018246azjrdzoqy.png
# Predicted: 5074BNJ, Ground Truth: 5074BNJ
# Image 423: /content/Dataset/License-Characters-by-2-27classes/train/ckj6oio3a001b246aq7mcduf7.png
# Predicted: 3580.ORA, Ground Truth: 3580DRA
# Image 424: /content/Dataset/License-Characters-by-2-27classes/train/ckie7cyxe005w246a9rqcl8nc.jpeg
# Predicted: 7836, Ground Truth: 7836VXJ
# Image 425: /content/Dataset/License-Characters-by-2-27classes/train/ckie8rxu1006t246aw13th8hy.jpeg
# Predicted: 2026, Ground Truth: 2026BBB
# Image 426: /content/Dataset/License-Characters-by-2-27classes/train/ckj6u892x0006246a4my81j0y.png
# Predicted: 82332, Ground Truth: 8233TZJ
# Image 427: /content/Dataset/License-Characters-by-2-27classes/train/ckn7cd7vt015e3068szo8o3o8.jpeg
# Predicted: 4949, Ground Truth: 4949UVB
# Image 428: /content/Dataset/License-Characters-by-2-27classes/train/ckid0tirs002r246aabj19q3u.jpeg
# Predicted: 8044, Ground Truth: 8044GVJ
# Image 429: /content/Dataset/License-Characters-by-2-27classes/train/ckj2qsf3k0005246a1uy4btd7.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 430: /content/Dataset/License-Characters-by-2-27classes/train/ckie91v9k006z246a3u51ygd9.jpeg
# Predicted: 6003TL, Ground Truth: 6003TLD
# Image 431: /content/Dataset/License-Characters-by-2-27classes/train/ckn7d936n008b3h66bt0vc5k8.jpeg
# Predicted: 3599JD, Ground Truth: 3599JDJ
# Image 432: /content/Dataset/License-Characters-by-2-27classes/train/ckicyxz7e001h246ap9zmlbb8.jpeg
# Predicted: 3264STA, Ground Truth: 3264STA
# Image 433: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rs8xo000u246a8lh22eg3.png
# Predicted: 6672QUA, Ground Truth: 6672BUA
# Image 434: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rjz8d000o246ahww7ixw0.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 435: /content/Dataset/License-Characters-by-2-27classes/train/ckid1d0gh0037246a0kae53jr.jpeg
# Predicted: 2199, Ground Truth: 2199GJZ
# Image 436: /content/Dataset/License-Characters-by-2-27classes/train/ckj6zi7th001f246ascfg9jup.png
# Predicted: 5732NX, Ground Truth: 5732NXD
# Image 437: /content/Dataset/License-Characters-by-2-27classes/train/ckicxfdv1000o246a8rz2otyd.jpeg
# Predicted: 6, Ground Truth: 4464HXB
# Image 438: /content/Dataset/License-Characters-by-2-27classes/train/ckie7tiyq0069246awtc36x4q.jpeg
# Predicted: AAA, Ground Truth: 1143AAA
# Image 439: /content/Dataset/License-Characters-by-2-27classes/train/ckicz5mvn001m246adc3vvpi8.jpeg
# Predicted: 5854, Ground Truth: 5854UDJ
# Image 440: /content/Dataset/License-Characters-by-2-27classes/train/ckn7dlc7m000m3h662lboqlob.jpeg
# Predicted: , Ground Truth: 8881XDB
# Image 441: /content/Dataset/License-Characters-by-2-27classes/train/ckie6e89n005b246a7z574kf2.jpeg
# Predicted: 2260, Ground Truth: 2260GVJ
# Image 442: /content/Dataset/License-Characters-by-2-27classes/train/ckie7ffbq005y246a1zpzxdcv.jpeg
# Predicted: 2806, Ground Truth: 2806SBA
# Image 443: /content/Dataset/License-Characters-by-2-27classes/train/ckicu2qge0004246aqxvb5nvw.jpeg
# Predicted: JBA, Ground Truth: 3690JBA
# Image 444: /content/Dataset/License-Characters-by-2-27classes/train/ckn75yfnb001m3068zfe58cyw.jpeg
# Predicted: , Ground Truth: 2ZVB
# Image 445: /content/Dataset/License-Characters-by-2-27classes/train/ckj6zt9ah001j246avjnppb6p.png
# Predicted: 5732NX, Ground Truth: 5732NXD
# Image 446: /content/Dataset/License-Characters-by-2-27classes/train/ckj6u1kxg0002246a2l9x47kt.png
# Predicted: 6507EGB, Ground Truth: 6507EGB
# Image 447: /content/Dataset/License-Characters-by-2-27classes/train/ckn77r47z00jc3068phq7x5u2.jpeg
# Predicted: 28072ve, Ground Truth: 2807ZVB
# Image 448: /content/Dataset/License-Characters-by-2-27classes/train/ckid1br0y0036246ajpcyt619.jpeg
# Predicted: 5920SAJ, Ground Truth: 5920SAJ
# Image 449: /content/Dataset/License-Characters-by-2-27classes/train/ckie7z8cf006d246ayq8yz5a0.jpeg
# Predicted: KSA, Ground Truth: 9454BKJ
# Image 450: /content/Dataset/License-Characters-by-2-27classes/train/ckie4tdaa0048246a0uuzadk9.jpeg
# Predicted: 5790, Ground Truth: 5790STA
# Image 451: /content/Dataset/License-Characters-by-2-27classes/train/ckid05ps5002a246a31dtk9tp.png
# Predicted: 8531EHA, Ground Truth: 8531EHA
# Image 452: /content/Dataset/License-Characters-by-2-27classes/train/ckie6jj9m005f246aq47fl68a.jpeg
# Predicted: 9378, Ground Truth: 9378BEJ
# Image 453: /content/Dataset/License-Characters-by-2-27classes/train/ckn7azkx000vz30681dukt0g6.jpeg
# Predicted: 6927N, Ground Truth: 6927NJJ
# Image 454: /content/Dataset/License-Characters-by-2-27classes/train/ckj6pse5q001i246akdwtnfbs.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 455: /content/Dataset/License-Characters-by-2-27classes/train/ckifkf1s3008v246aep91ayw6.jpeg
# Predicted: 2737LSD, Ground Truth: 2737LSD
# Image 456: /content/Dataset/License-Characters-by-2-27classes/train/ckn75vzi80019306874pvuexa.jpeg
# Predicted: 27112ND, Ground Truth: 2711ZND
# Image 457: /content/Dataset/License-Characters-by-2-27classes/train/ckie5zvy10050246ae41llx0q.jpeg
# Predicted: 3100, Ground Truth: 3100NKD
# Image 458: /content/Dataset/License-Characters-by-2-27classes/train/ckn77vabg00kl3068mhzdrnvq.jpeg
# Predicted: 7194NRA, Ground Truth: 7194NRA
# Image 459: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rhejf000m246azba1owt8.png
# Predicted: 6672BUA, Ground Truth: 6672BUA
# Image 460: /content/Dataset/License-Characters-by-2-27classes/train/ckid0w0kb002t246as4lqa3ja.jpeg
# Predicted: 1759, Ground Truth: 1759LRD
# Image 461: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rbzak000i246a29ubfv5x.png
# Predicted: 2039SZA, Ground Truth: 2039SZA
# Image 462: /content/Dataset/License-Characters-by-2-27classes/train/ckicuba190008246a3sunoeg2.jpeg
# Predicted: 7158, Ground Truth: 7158GGA
# Image 463: /content/Dataset/License-Characters-by-2-27classes/train/ckj6owrok001c246axlu0r25h.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 464: /content/Dataset/License-Characters-by-2-27classes/train/ckie953aj0071246a402u48ju.jpeg
# Predicted: 7375TRJ, Ground Truth: 77JTR
# Image 465: /content/Dataset/License-Characters-by-2-27classes/train/ckid1vq01003k246agzbe1dlo.jpeg
# Predicted: 4304, Ground Truth: 4304RUJ
# Image 466: /content/Dataset/License-Characters-by-2-27classes/train/ckie7gksk005z246akdmzu66p.jpeg
# Predicted: 9778, Ground Truth: 9778RDJ
# Image 467: /content/Dataset/License-Characters-by-2-27classes/train/ckj6ru2jm001l246a48ozfr0q.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 468: /content/Dataset/License-Characters-by-2-27classes/train/ckid13acf002z246aqquux1u1.jpeg
# Predicted: 2199, Ground Truth: 2199GZJ
# Image 469: /content/Dataset/License-Characters-by-2-27classes/train/ckiflk39s009h246ayiq0t2tz.jpeg
# Predicted: L, Ground Truth: 2583NLB
# Image 470: /content/Dataset/License-Characters-by-2-27classes/train/ckie9h3v90078246aewo9cszp.jpeg
# Predicted: , Ground Truth: 7147VXA
# Image 471: /content/Dataset/License-Characters-by-2-27classes/train/ckicz22ot001k246arlafx3nv.jpeg
# Predicted: 4698, Ground Truth: 4698LZJ
# Image 472: /content/Dataset/License-Characters-by-2-27classes/train/ckie4cimr003x246aoznobsso.jpeg
# Predicted: 5349, Ground Truth: 5349LVJ
# Image 473: /content/Dataset/License-Characters-by-2-27classes/train/ckie8bzqw006j246a867csyyq.jpeg
# Predicted: KSA, Ground Truth: 5542BVJ
# Image 474: /content/Dataset/License-Characters-by-2-27classes/train/ckid0mio0002m246adn07btx6.jpeg
# Predicted: 2806, Ground Truth: 2806SBA
# Image 475: /content/Dataset/License-Characters-by-2-27classes/train/ckj2qr3rk0004246a7jdudo8p.png
# Predicted: 5732NX0, Ground Truth: 5732NXD
# Image 476: /content/Dataset/License-Characters-by-2-27classes/train/ckie5e0an004m246au3hmya6z.jpeg
# Predicted: 3795, Ground Truth: 3795EAX
# Image 477: /content/Dataset/License-Characters-by-2-27classes/train/ckn7d6qv001ea3068n03uk9t5.jpeg
# Predicted: 7997NG, Ground Truth: 7799HGD
# Image 478: /content/Dataset/License-Characters-by-2-27classes/train/ckie4fc96003z246a76ac4qzq.jpeg
# Predicted: 3337, Ground Truth: 3337LTD
# Image 479: /content/Dataset/License-Characters-by-2-27classes/train/ckie6zqxs005m246are0x3fmb.jpeg
# Predicted: 6003, Ground Truth: 6003TLD
# Image 480: /content/Dataset/License-Characters-by-2-27classes/train/ckifjwt8j008i246anvknmto5.jpeg
# Predicted: 1112, Ground Truth: 1112SDD
# Image 481: /content/Dataset/License-Characters-by-2-27classes/train/ckj6safwg001p246al4ktzyus.png
# Predicted: 5732NXD, Ground Truth: 5732NXD
# Image 482: /content/Dataset/License-Characters-by-2-27classes/train/ckie7w25o006b246aoh4rupar.jpeg
# Predicted: 3757, Ground Truth: 3757JED
# Image 483: /content/Dataset/License-Characters-by-2-27classes/train/ckj6utyqc000o246ai9w7t569.png
# Predicted: 2322TZJ, Ground Truth: 2322TZJ
# Image 484: /content/Dataset/License-Characters-by-2-27classes/train/ckid1257p002y246aa23kaopk.jpeg
# Predicted: 2264JKB, Ground Truth: 2264JKB
# Image 485: /content/Dataset/License-Characters-by-2-27classes/train/ckid0gu9c002i246a90xe99zp.jpeg
# Predicted: 1077, Ground Truth: 1077VDD
# Image 486: /content/Dataset/License-Characters-by-2-27classes/train/ckie8tqd6006u246ad5khd9m0.jpeg
# Predicted: 8918NLJ, Ground Truth: 8918NLJ
# Image 487: /content/Dataset/License-Characters-by-2-27classes/train/ckn7b42rh00xt3068la1z4fjx.jpeg
# Predicted: 8052, Ground Truth: 8052VVJ
# Image 488: /content/Dataset/License-Characters-by-2-27classes/train/ckj2r7p5x000f246a2e8w64z3.png
# Predicted: 3461GZJ, Ground Truth: 3461GZJ
# Image 489: /content/Dataset/License-Characters-by-2-27classes/train/ckj6v531k000w246am785cegk.png
# Predicted: 5732NX0, Ground Truth: 5732NXD
# Image 490: /content/Dataset/License-Characters-by-2-27classes/train/ckn7dhjmw00ah3h6665lnlr86.jpeg
# Predicted: 4225GSD, Ground Truth: 4225GSD
# Image 491: /content/Dataset/License-Characters-by-2-27classes/train/ckn77aqr000ey3068vt4m50xm.jpeg
# Predicted: 5850RBJ, Ground Truth: 5850RBJ
# Image 492: /content/Dataset/License-Characters-by-2-27classes/train/ckie7lbdq0063246a5oe40sof.jpeg
# Predicted: KSA, Ground Truth: 1112SDD
# Image 493: /content/Dataset/License-Characters-by-2-27classes/train/ckid0aey1002d246a4yttijxq.jpeg
# Predicted: , Ground Truth: 4698LZJ
# Image 494: /content/Dataset/License-Characters-by-2-27classes/train/ckj6ub4270008246akk6t7krn.png
# Predicted: 3673TND, Ground Truth: 3673TND
# Image 495: /content/Dataset/License-Characters-by-2-27classes/train/ckj2rnu4i000r246az9i86wmk.png
# Predicted: 2948UR, Ground Truth: 2948URD
# Image 496: /content/Dataset/License-Characters-by-2-27classes/train/ckicy4o3z0013246arqlvht46.jpeg
# Predicted: 3754VLJ, Ground Truth: 3754VLJ

# %%
image_path = '/content/8.jpg'
ocr_results = ocr.ocr(image_path,det=True,cls=False,rec=True)
# Out:
# [2024/09/30 15:30:21] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03303122520446777
# [2024/09/30 15:30:21] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11526274681091309

# %%
# ocr_results
# Out:
# [[('A9E!', 0.2918105125427246)]]

# %%
# labels[0], predicted_texts[1]
# Out:
# ('7090HHJ', '')

# %%
# !wget https://paddleocr.bj.bcebos.com/rec/ch/ch_PP-OCRv3_rec_train.tar
# !tar -xvf ch_PP-OCRv3_rec_train.tar
# Out:
# tar: ch_PP-OCRv3_rec_train.tar: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now
