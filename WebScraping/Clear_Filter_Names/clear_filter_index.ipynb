# %% [markdown]
# ## Import & Initialize

# %%
import os
import time
from datetime import datetime
from dotenv import load_dotenv

import googlemaps
import gmplot

import pandas as pd

import re
from difflib import SequenceMatcher
from fuzzywuzzy import fuzz

# %%
load_dotenv()
API_KEY = os.getenv('GOOGLE_MAPS_API_KEY_3')

# %%
gmaps = googlemaps.Client(key=API_KEY)

# %% [markdown]
# ## Filter Road Names (Didn't Work)

# %%
def clean_road_name(road_name):
    road_name = road_name.lower()
    road_name = re.sub(r'[^\w\s]', '', road_name)
    return road_name

def are_similar(name1, name2, threshold=0.8):
    similarity = SequenceMatcher(None, name1, name2).ratio()
    return similarity >= threshold

# %%
def get_geocode(road_name, city="Riyadh", country="Saudi Arabia"):

    queries = [road_name, f"{road_name}, {city}", f"{road_name}, {city}, {country}"]
    
    for query in queries:
        geocode_result = gmaps.geocode(query)
        if geocode_result:
            location = geocode_result[0]['geometry']['location']
            return location['lat'], location['lng']
    
    return None, None

# %%
def get_traffic_data(road_name):
    try:
        origin_lat, origin_lng = get_geocode(road_name + " start")
        destination_lat, destination_lng = get_geocode(road_name + " end")
        
        if origin_lat is None or destination_lat is None:
            print(f"Error getting geocodes for {road_name}")
            return None

        origin = f"{origin_lat},{origin_lng}"
        destination = f"{destination_lat},{destination_lng}"
        
        traffic_data = gmaps.distance_matrix(origins=origin, 
                                            destinations=destination, 
                                            mode="driving", 
                                            departure_time="now")
        element = traffic_data['rows'][0]['elements'][0]
        
        if 'duration_in_traffic' in element:
            traffic_duration = element['duration_in_traffic']['value']
        elif 'duration' in element:
            traffic_duration = element['duration']['value']
            print(f"Traffic data not available for {road_name}, using regular duration")
        else:
            print(f"No duration data found for {road_name}")
            return None

        return traffic_duration
    except Exception as e:
        print(f"Error getting traffic data for {road_name}: {e}")
        return None

# %%
def deduplicate_roads(road_list):
    cleaned_roads = []
    unique_roads = []
    
    for road in road_list:
        cleaned_name = clean_road_name(road)
        
        if not any(are_similar(cleaned_name, clean_road_name(r)) for r in unique_roads):
            unique_roads.append(road)
    
    return unique_roads

# %%
def rank_roads_by_traffic(roads):
    road_traffic = []
    
    for road in roads:
        traffic = get_traffic_data(road)
        if traffic is not None:
            road_traffic.append((road, traffic))
    
    road_traffic.sort(key=lambda x: x[1], reverse=True)
    return road_traffic[:200]

# %%
def get_top_200_traffic_roads(road_list):
    unique_roads = deduplicate_roads(road_list)

    top_200_roads = rank_roads_by_traffic(unique_roads)
    
    return top_200_roads


top_200_roads = get_top_200_traffic_roads(all_roads)

for road, traffic in top_200_roads:
    print(f"{road}: {traffic} seconds of traffic delay")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       8     return top_200_roads
#      10 # Get top 200 roads with the highest traffic
# ---> 11 top_200_roads = get_top_200_traffic_roads(all_roads)
#      13 # Display the results
#      14 for road, traffic in top_200_roads:
#
# NameError: name 'all_roads' is not defined

# %%
len(top_200_roads)
# Out:
# 200

# %% [markdown]
# ## Clean Data

# %%
with open("unique_road_names.txt", "r") as f:
    loaded_road_names = set(line.strip() for line in f)

# %%
def remove_duplicate_roads(road_names):
    unique_roads = []
    threshold = 80 
    for road in road_names:
        if not any(fuzz.ratio(road, unique) > threshold for unique in unique_roads):
            print(f"Original road count: {road}")
            unique_roads.append(road)
    
    return unique_roads

cleaned_roads = remove_duplicate_roads(loaded_road_names)
# Out:
# Original road count: دير البلح
# Original road count: القدوة
# Original road count: وادي الفرع
# Original road count: Mohammed Bin Moslem
# Original road count: شارع أبو علي الهجري
# Original road count: علي الأحمر
# Original road count: شارع فاس
# Original road count: AL Mereeikheya
# Original road count: الحريري
# Original road count: طريق ديراب
# Original road count: عبدالله البسام
# Original road count: No. 80
# Original road count: سليمان بن داود
# Original road count: عبدالرزاق الجيلي
# Original road count: ابن غيث
# Original road count: عصمة الأسدي
# Original road count: ابن شاهين
# Original road count: سعد بن الربيع
# Original road count: زيد بن الخطاب
# Original road count: ابن الأصبح
# Original road count: ابن الفصيح
# Original road count: Barqah
# Original road count: Al Hayathem
# Original road count: عبيد الله بن يزيد
# Original road count: أبي القاسم الوراق
# Original road count: شارع الجائزة
# Original road count: المشياح
# Original road count: علي الموازيني
# Original road count: أبي محمد بن المظفر
# Original road count: شهاب الدين بن ماجد
# Original road count: العلايا
# Original road count: Al Marmar
# Original road count: Al Tamr
# Original road count: محمد اليزيدي
# Original road count: سالم الشرقاوي
# Original road count: شارع الأصيل
# Original road count: شارع رأس الأرض
# Original road count: بكر المازني
# Original road count: معقل بن خويلد
# Original road count: الخرجان
# Original road count: آمنة بنت عنان
# Original road count: خفاجة بن سفيان
# Original road count: محمد بن بشار
# Original road count: سعيد بن جودت
# Original road count: دقاف
# Original road count: حمد بن يحيى بن غيهب
# Original road count: شارع الشعبة الشامي
# Original road count: شارع أسماء بن خالد بن عوف البارقي
# Original road count: الكراني
# Original road count: Qatada Al Basri
# Original road count: بني نعيم
# Original road count: حميدة الإبراهيمي
# Original road count: شارع الحديثة
# Original road count: أبلق
# Original road count: رقم 319
# Original road count: كعب بن زهير
# Original road count: ال طويل
# Original road count: الهام
# Original road count: أعشى همدان
# Original road count: عبدالله بن عبداللطيف آل الشيخ
# Original road count: الشيخ علي عبدالله الطيب المدني
# Original road count: أرسلان
# Original road count: Oibrahim Ibn Obeida
# Original road count: الامواه
# Original road count: Soweiga
# Original road count: Mohammed Bin Sultan
# Original road count: الصهيد
# Original road count: شارع شهيد الدين ثم الوطن عبدالله عبدالرحمن المنصور
# Original road count: ثمامة بن أثال
# Original road count: أبي عبدالله الواعظ
# Original road count: شارع خليل المالقي
# Original road count: التمامي
# Original road count: Al Askandarona
# Original road count: آل داود
# Original road count: آل حمود
# Original road count: شارع الغريف
# Original road count: محمد المغربي
# Original road count: التغلبي
# Original road count: سليمان بن مقبل
# Original road count: الربيعة
# Original road count: أبي عبدالله السبتي
# Original road count: الحسين بن أبي القاسم
# Original road count: ممر 98
# Original road count: 38
# Original road count: شارع مدينة الزايد
# Original road count: Al Khariba
# Original road count: ابن يحيى المالكي
# Original road count: عبدالقادر الجزائري
# Original road count: البراعم
# Original road count: الحجبة
# Original road count: Khzam
# Original road count: آل سليمان
# Original road count: المعابدة
# Original road count: فضالة بن عبدالله
# Original road count: أمان بن الحكم
# Original road count: الرقبان
# Original road count: الجرد
# Original road count: أبي إسحاق المعري
# Original road count: أبي الفتح الثقفي
# Original road count: البرادي
# Original road count: Ahmad Al Bahiqi
# Original road count: الرديني
# Original road count: عسيلان
# Original road count: أبي عبدالله بن عبدالجبار
# Original road count: Abi Yahia Al Saqafee
# Original road count: تمير
# Original road count: العوفي
# Original road count: Al Barak
# Original road count: عبدالواحد الموفق
# Original road count: أحمد بن دحيم
# Original road count: وادي ملحة
# Original road count: ثلاب بن حمد
# Original road count: شارع الكاسب
# Original road count: الزويدية
# Original road count: شارع ابن الخراساني
# Original road count: Al Ataf
# Original road count: Abdulrahman Al Fadli
# Original road count: شارع عمر بن عبدالعزيز
# Original road count: Abdullah Ben Saheem
# Original road count: علي القارئ
# Original road count: شارع فهاد محمد آل جفيران
# Original road count: ممر أبي المنصور الخزرجي
# Original road count: Amir Bin Owf
# Original road count: شارع الفراديس
# Original road count: شارع ابن زيان
# Original road count: Mohammed Bin Al Moali
# Original road count: ممر انس بن النصر
# Original road count: أبي السعود القسطلاني
# Original road count: الموية الجديد
# Original road count: إبراهيم بن صبيح
# Original road count: أحمد بن محمد الدلوالي
# Original road count: الحرملية
# Original road count: محمد بن دينار
# Original road count: فروة بن عمرو
# Original road count: شارع شعبة الطهوي
# Original road count: محمد بن اللباد
# Original road count: ريما الشمالي
# Original road count: No. 105
# Original road count: الوهط
# Original road count: ابن علي الفاسي
# Original road count: الشيخ محمد بن مانع
# Original road count: أبي الحسن اليزيدي
# Original road count: هشام بن حجيرة
# Original road count: رقم 308
# Original road count: عثمان بن الخطيب
# Original road count: محمد الكثامي
# Original road count: Al Hareth
# Original road count: بندر راشد على العميرة
# Original road count: شارع جبل أشاقر
# Original road count: الخفيسة
# Original road count: الأصيحر
# Original road count: نخال
# Original road count: تركي محمد غراف العتيبي
# Original road count: السيوطي
# Original road count: No. 122
# Original road count: شارع عكرمة بن ابي جهل
# Original road count: شريح الحجازي
# Original road count: عبيد الخزاعي
# Original road count: ابن شعلة
# Original road count: aljamiha
# Original road count: شارع خالد بن سنان العبسي
# Original road count: حمزة الجعلي
# Original road count: Hunaider St.
# Original road count: Al Magharabi
# Original road count: الصبح
# Original road count: لؤلؤة
# Original road count: محمد بن أبي طالب
# Original road count: حسين بن محمد العصامي
# Original road count: أبي حاتم الرازي
# Original road count: المليحة السفلى
# Original road count: سفيان بن عبدالرحمن
# Original road count: البجادية
# Original road count: القرشة
# Original road count: بنغازي
# Original road count: عبدالله بن يحنس
# Original road count: سعد الهمذاني
# Original road count: عبدالرحمن بن خلدون
# Original road count: سلطانة
# Original road count: الحاير
# Original road count: المسيل
# Original road count: شارع الأمير فواز بن عبدالعزير
# Original road count: المجاز
# Original road count: دليهان
# Original road count: شارع ابي بكر الباقلاني
# Original road count: سليم بن قيس
# Original road count: Prince Musa'ed Bin Abdulaziz St.
# Original road count: الروايا
# Original road count: وادي الصحن
# Original road count: أبي علي بن الشريف
# Original road count: الحارث بن الربيع
# Original road count: شارع نعمان بن مقرن المزني
# Original road count: وادي رخام
# Original road count: طريق المجمعة الأرطاوية
# Original road count: شارع علي بن عبدالرحيم
# Original road count: القاسمي
# Original road count: عبدالرحمن بخش
# Original road count: جبل الأثريات
# Original road count: ابن أبي بكر المخزومي
# Original road count: رقم 124
# Original road count: شارع المحيط
# Original road count: عبدالغني مشرف
# Original road count: شارع طوير
# Original road count: القاسم الدمشقي
# Original road count: شارع إبراهيم بن أحمد الزعبلي
# Original road count: No. 17
# Original road count: طريق مكة الفرعي
# Original road count: No. 393
# Original road count: الفضل بن العباس
# Original road count: المبارك بن الأثير
# Original road count: أحمد المستنير
# Original road count: وادي القصر
# Original road count: رشيد أيوب
# Original road count: الضحى
# Original road count: Rakham Valley
# Original road count: الامير فيصل بن تركي بن عبد العزيز
# Original road count: Kahlaa
# Original road count: الغبيرات
# Original road count: شارع أحمد بن الحجاج
# Original road count: سمحا
# Original road count: جبل العوينات
# Original road count: Al Job
# Original road count: الرياضة
# Original road count: أبي محمد الترسابادي
# Original road count: المواسمة
# Original road count: No. 65
# Original road count: Al Qalib
# Original road count: رقم 158
# Original road count: فائد بن حبيب
# Original road count: الفور
# Original road count: حصن جبرين
# Original road count: 20
# Original road count: Al-'Aziziah Road
# Original road count: أبي جعفر السلمي
# Original road count: شارع بلال بن هرمي
# Original road count: شارع جبل الحسي
# Original road count: إسلام أباد
# Original road count: أحمد بن يوسف الكواشي
# Original road count: سبط السعودي
# Original road count: ممر عبدالرحمن بن عمر بن حزام
# Original road count: مبيهة
# Original road count: بيت المراح
# Original road count: Abi Al-Hasan As-Salmi
# Original road count: دهيثان
# Original road count: شارع القاضي إياس
# Original road count: حميد بن قحطبة
# Original road count: Al Shaalaniya
# Original road count: ابن النديم
# Original road count: الرمث
# Original road count: Thumamah Road
# Original road count: محمد بن عبدالرحمن السخاوي
# Original road count: ابن عبد ربه
# Original road count: حكيم بن الحارث
# Original road count: شارع الوقار
# Original road count: عبدالرحمن الأنصاري
# Original road count: يونس المليجي
# Original road count: طريق خريص
# Original road count: عبدالله بن أبي محمد
# Original road count: Abi Hemeidan
# Original road count: ممر زامل الخطيب
# Original road count: قتادة بن النعمان
# Original road count: غزير
# Original road count: المعيزيلة
# Original road count: حسن الفلقي
# Original road count: السيرافي
# Original road count: ثابت النحوي
# Original road count: طلعت عمار
# Original road count: الربيع بن خثيم
# Original road count: شارع البداح
# Original road count: Soliman Bin Khalaf
# Original road count: القصر الكبير
# Original road count: Al Jarira Valley
# Original road count: ابن قبيصة
# Original road count: حمود عائض فهد الحربي
# Original road count: عباس بن جعفر بن صديق
# Original road count: Faleh Mahdi Al Mahdi
# Original road count: شارع رقم 400
# Original road count: علي بن أبي منصور الأزدي
# Original road count: عمر بن ذر
# Original road count: مزرعة البستان
# Original road count: أبي الثناء محمود العدل
# Original road count: علي بن أحمد البلوي
# Original road count: 5th Roundabout
# Original road count: Al Nadwah
# Original road count: شارع عبدالرحمن الهندي
# Original road count: المستنصر الأموي
# Original road count: Saeed Bin Nafeel
# Original road count: Al Wajih
# Original road count: الشريف الرضي
# Original road count: مقمور
# Original road count: السلوى
# Original road count: الخفجة
# Original road count: Al Khozama
# Original road count: لبي العلا محمد بن الفقية
# Original road count: Al Imam S'Aud Bin Abdulaziz Bin Mohammed
# Original road count: إبراهيم بن محمد الدميري
# Original road count: إبراهيم الشيرازي
# Original road count: مسور
# Original road count: Al Bayaa
# Original road count: يعقوب بن داود
# Original road count: ابن قتيدة
# Original road count: شارع رقم 211
# Original road count: آبار الماشي
# Original road count: No. 32
# Original road count: Al-Abbas Al Ghanwal
# Original road count: شارع أبي حفص الدارقطني
# Original road count: العلاء بن محمد
# Original road count: محمد بن عبدالحكم
# Original road count: Abi Bakar Al Katbi
# Original road count: محمد الحراني
# Original road count: أشهب العامري
# Original road count: البكري الصديقي
# Original road count: أبي علي المجاور
# Original road count: بدائع بن نجم
# Original road count: شارع راشد الحبراني
# Original road count: Al Mahalaani
# Original road count: أبي حفص السعدي
# Original road count: عبدالباقي الحنائي
# Original road count: رقم 166
# Original road count: جعفر السقاف
# Original road count: Mahbouba
# Original road count: شارع عبدالله بن مالك
# Original road count: حسين بن محمد بن عبدالوهاب
# Original road count: Najran
# Original road count: الحسن القرشي
# Original road count: أصيلة
# Original road count: ممر33
# Original road count: أحمد برزنجي
# Original road count: الحجاريف
# Original road count: إبراهيم النووي
# Original road count: شارع الأمير سلطان بن سلمان بن عبدالعزيز
# Original road count: مشرق
# Original road count: غيانة
# Original road count: وادي الليسن
# Original road count: J Street
# Original road count: جبل الظنة
# Original road count: 13
# Original road count: شارع إبراهيم النفيسي
# Original road count: القزويني
# Original road count: الصافح
# Original road count: رباح اللخمي
# Original road count: ابن الشيخ
# Original road count: حارثه بن عدي
# Original road count: رقم 235
# Original road count: ملفى مساعد السحيمى
# Original road count: ابن المادح
# Original road count: الجيرة
# Original road count: منصور بن المبارك
# Original road count: العجلية
# Original road count: الحروف
# Original road count: ممر الدغيمة
# Original road count: عبدالقادر الرهاوي
# Original road count: الحدبه
# Original road count: رقم 376
# Original road count: عبدالله المغازلي
# Original road count: الروضة
# Original road count: Atia
# Original road count: يحيى المصمودي
# Original road count: شارع زين بن احمد
# Original road count: Al Haba
# Original road count: شارع ابن محمد العافري
# Original road count: شارع أبي ايوب اليمامي
# Original road count: Prince Faisal Bin Fahad Bin Abdualaziz
# Original road count: نوفل العامري
# Original road count: حمزة بوقري
# Original road count: Al Masawer
# Original road count: حشاش العرجاني
# Original road count: ممر المقدام بن معد يكرب
# Original road count: شارع الفالق
# Original road count: الرون
# Original road count: الأعاضيد
# Original road count: ابن نجم
# Original road count: شارع عبيدة بن الحارث
# Original road count: أبي علي الكناني
# Original road count: At-Tabri
# Original road count: شارع الدويم
# Original road count: الدار السفلى
# Original road count: الداهسية
# Original road count: أم الشبرم
# Original road count: محمد البشير
# Original road count: عبدالملك بن رزين
# Original road count: Ahmed Abn Alkashab
# Original road count: العوشن
# Original road count: الرونة العليا
# Original road count: عبدالرحمن العقيل
# Original road count: جمال الدين النويري
# Original road count: أبي مصعب الزهري
# Original road count: السمرة
# Original road count: أبي المنصور النجيب
# Original road count: Al Ghamasia
# Original road count: هبة الله الكاتب
# Original road count: الحافظ الواسطي
# Original road count: شارع الهفوف
# Original road count: Watar
# Original road count: سالم بن شوال
# Original road count: الحسن الكوفي
# Original road count: العلوب
# Original road count: ظلماء
# Original road count: حضارة
# Original road count: إبراهيم الطيبي
# Original road count: Ali Bin Mohab
# Original road count: عون الخزاعي
# Original road count: الشعبة
# Original road count: Toweir
# Original road count: علي أبي نمي
# Original road count: Dammam Road
# Original road count: حسن بن منديل
# Original road count: ممر 157
# Original road count: Jazirat Aqour
# Original road count: شارع ضيدة
# Original road count: أم الخير
# Original road count: شارع أيوب بن باديس
# Original road count: سومطرة
# Original road count: قليتة
# Original road count: المحلة الكبرى
# Original road count: البحتري
# Original road count: وادي مرفود
# Original road count: Al Ibsat
# Original road count: البحور
# Original road count: Aka
# Original road count: المحافظ
# Original road count: رقم 26
# Original road count: عبدالله بن محمد المطري
# Original road count: محمد عارف الجاوي
# Original road count: شارع أحمد بن محمد الرعيني
# Original road count: رقم 73
# Original road count: Al Ghadaq
# Original road count: Al Maktabah
# Original road count: عبدالله بن خنيفر
# Original road count: عيسى الثعالبي
# Original road count: عبدالوهاب الأنماطي
# Original road count: محمد رشيد رضا
# Original road count: خليج تونس
# Original road count: هلال التميمي
# Original road count: شارع محمد بن عباس بن نضلة
# Original road count: شارع بدر
# Original road count: الشيخ
# Original road count: أبي عبيدة النابلسي
# Original road count: أم أثلة
# Original road count: المحاربي
# Original road count: عبدالمنعم بن الفقيه
# Original road count: الأخطبة
# Original road count: الصفيف
# Original road count: Abdulaziz Bin Shabanah St.
# Original road count: Lina
# Original road count: أبي الفتح بن رزين
# Original road count: عبدالرحمن حجي
# Original road count: صدقة الوكيل
# Original road count: Idris Bin Othman
# Original road count: أحمد الرشيدي
# Original road count: جبل اليمامة
# Original road count: Mohammed Bin Gshian
# Original road count: الرصينية
# Original road count: الحسامة
# Original road count: Al Aisan
# Original road count: أحمد بن الفضل بن محمد باكثير
# Original road count: ابن الخصيب الدمشقي
# Original road count: إسحاق القراب
# Original road count: علي السنجاري
# Original road count: الفريق
# Original road count: شارع وادي أزيمة
# Original road count: 162
# Original road count: حمزة البغدادي
# Original road count: فيروز العبد العزيز
# Original road count: شارع علاء الدين ثابت
# Original road count: دالج
# Original road count: Al teif
# Original road count: أبيض البارقي
# Original road count: الوريكة
# Original road count: أبي بن أمية الليثي
# Original road count: سليمان بن حمزة
# Original road count: أبي سرحة
# Original road count: الشموس
# Original road count: شارع سبأ
# Original road count: أبي الفتوح الواعظ
# Original road count: أحمد محمد جمال
# Original road count: الخضر بن كامل
# Original road count: جنادة الهروي
# Original road count: ابن باديس
# Original road count: شارع أم حزم UMM HAZEM STREET
# Original road count: الشرف
# Original road count: عبدالله بن جابر
# Original road count: أبي شجاع بن المعلم
# Original road count: عبدالرحمن بن أبي ياسر
# Original road count: شارع واقد بن عبدالله
# Original road count: عرين
# Original road count: شارع أبي السعادات المبارك
# Original road count: الرواجح
# Original road count: شارع اليسع بن عيسى
# Original road count: Al Anan
# Original road count: عبيدة بن ربيعة
# Original road count: جبل المسعودية
# Original road count: آل هداب
# Original road count: Al Qalsawi
# Original road count: Meskan
# Original road count: حبيرا
# Original road count: الخفق الجنوبي
# Original road count: حايط الماء
# Original road count: وادي أبي عرب
# Original road count: سلمة بن صخر
# Original road count: Al Rasha Valley
# Original road count: عتيق بن يحيى
# Original road count: شارع عبدالله الهمذاني
# Original road count: محمد بن هندي
# Original road count: No.466
# Original road count: المنصور بن أبي عامر
# Original road count: صدقة الحراني
# Original road count: عساف بن محيا
# Original road count: Al Matr
# Original road count: شارع بني سويف
# Original road count: أبراد
# Original road count: الصندل
# Original road count: أبي الدرداء
# Original road count: عيسى بن عبدالله الجريوي
# Original road count: Al Sous Valley
# Original road count: شارع محمد العبدري
# Original road count: مسهر بن النعمان
# Original road count: عبدالواحد الجوهري
# Original road count: روح بن صالح
# Original road count: المعاسير
# Original road count: Mahayeda
# Original road count: اسيد بن الأخنس
# Original road count: عبدالجبار بن الورد
# Original road count: تقية بنت ابي سعيد
# Original road count: شارع الأطلال
# Original road count: الامير محمد بن عبدالله بن عبدالرحمن
# Original road count: البكري
# Original road count: الإمام سعود بن عبد العزيز بن محمد الفرعي
# Original road count: أبي الفتح يحيى البيع
# Original road count: الروق
# Original road count: شارع إسماعيل المزني
# Original road count: أبي الربيع
# Original road count: الفوالجة
# Original road count: Shelal
# Original road count: الأمير عبدالإله بن عبدالعزيز
# Original road count: Bilal Bin Rabah
# Original road count: المدية
# Original road count: عبدالرحيم الخطيب
# Original road count: No. 308
# Original road count: Al Jarshi
# Original road count: شهاب الدين الغزي
# Original road count: الفضيلة
# Original road count: إبراهيم بن جمعان
# Original road count: عبدالله الصنهاجي
# Original road count: أبي بدية
# Original road count: Al Howeimeda
# Original road count: شارع أبي طالب عبدالجبار
# Original road count: الرازي البغدادي
# Original road count: حمزة شحاتة
# Original road count: ممر عبدالواحد بن أحمد
# Original road count: شارع أسيلة
# Original road count: التاج
# Original road count: المليداء
# Original road count: شارع أوس بن قتادة
# Original road count: زهر اللؤلؤ
# Original road count: Al Asilah
# Original road count: جبل أبلي
# Original road count: أبي جعفر الرعيني
# Original road count: بهلاء
# Original road count: ابن كعب
# Original road count: مرجان
# Original road count: الجبل الأبيض
# Original road count: Abdullah Al Sharif
# Original road count: علي الواعظ
# Original road count: 98
# Original road count: اللواء
# Original road count: طريق أميه الذيب
# Original road count: Al Bateiha
# Original road count: الحسن الأندلسي
# Original road count: الشبارقة
# Original road count: الناضورة
# Original road count: صالح الطاسان
# Original road count: أبي السعود البصري
# Original road count: As Salah
# Original road count: الشلال
# Original road count: اللوز
# Original road count: رقم 414
# Original road count: السقطي
# Original road count: الحسن الخلال
# Original road count: يوسف المفيد
# Original road count: عبدالغني الدميري
# Original road count: عز الدين الذاري
# Original road count: Ibn Al Tofeil
# Original road count: المفضل الضبي
# Original road count: جعفر الأفضلي
# Original road count: عثمان بن الأسود
# Original road count: شارع الأنماطي
# Original road count: Enab
# Original road count: جدعاء
# Original road count: شارع رافع بن خديج الأنصاري
# Original road count: الخزان
# Original road count: قباء
# Original road count: الزيني بن ظهيرة
# Original road count: عبدالكريم بن هيثم
# Original road count: الجاعد بن الشماخ
# Original road count: ابن خيثمة
# Original road count: قرية الأشراف
# Original road count: عنيزة
# Original road count: كلثوم العتابي
# Original road count: أحمد بن محمد القرطبي
# Original road count: Mohammed Bin Zarqoun
# Original road count: ابن نفطوية
# Original road count: الأحمر بن مازن
# Original road count: طريق المجمعة - بوضاء
# Original road count: هارون الدمشقي
# Original road count: النظايم
# Original road count: جرير بن حازم
# Original road count: شارع جسير
# Original road count: ابن أهبان
# Original road count: حصن القابل
# Original road count: سالم بن عبدالله البصري
# Original road count: الخوخ
# Original road count: الاويسط
# Original road count: No. 294
# Original road count: طريق كرنيش الرياض
# Original road count: 115
# Original road count: الشلفاء
# Original road count: صالح بن عذل
# Original road count: يعقوب الكندي
# Original road count: ميرزا إبراهيم الكازروني
# Original road count: التعليم
# Original road count: Hibat Allah Bin Ibrahim
# Original road count: عبدالخالق الهاشمي
# Original road count: ابن هلال الفلالي
# Original road count: الجحفة
# Original road count: شارع سعيد بن زيد
# Original road count: Al Najd Path
# Original road count: شارع وادي الميادي
# Original road count: الجنادل
# Original road count: Jadaar Alaslami
# Original road count: المعذر
# Original road count: بويسط
# Original road count: Al Thana
# Original road count: ابن الأمير
# Original road count: شارع أحمد الفريابي
# Original road count: أبي موسى المديني
# Original road count: جبل طوروس
# Original road count: أبي محمد بن الزوال
# Original road count: ممر عبادة بن بشر
# Original road count: أحمد بن بركة
# Original road count: ابن كليب
# Original road count: وادي الزرقاء
# Original road count: عين شمس
# Original road count: ابن خير الأشبيلي
# Original road count: علي بابصيل
# Original road count: نور الدين السندي
# Original road count: الدقائق
# Original road count: ممر راشد الينبعي
# Original road count: ابن الصباغ الخزرجي
# Original road count: Al-Basala
# Original road count: ال الظفيرى
# Original road count: الجبيهة
# Original road count: بئر رومة
# Original road count: وادي الكردي
# Original road count: باب الجنان
# Original road count: ابن عطيون التجيبي
# Original road count: جميل الزهاوي
# Original road count: عبدالعزيز بن خلف السلمي
# Original road count: شارع الظهراني
# Original road count: إبراهيم بن الأحمدي
# Original road count: BRT12 connection
# Original road count: شارع أم النور
# Original road count: ربوعة
# Original road count: شارع أبي حنيفة الدينوري
# Original road count: ظبية بنت البراء
# Original road count: خويتم
# Original road count: الهفوف
# Original road count: الرودكي
# Original road count: Abdulrahman Al Odwan
# Original road count: No. 136
# Original road count: قثم بن العباس
# Original road count: وادي شكيل
# Original road count: زكريا الأنصاري
# Original road count: عبدالجليل برادة
# Original road count: مهيار الديلمي
# Original road count: Al Khalif
# Original road count: سيال
# Original road count: الأمن
# Original road count: القميش
# Original road count: المهد
# Original road count: البواردي
# Original road count: آل محيرق
# Original road count: عبدالمجيد الخطي
# Original road count: عثمان بن عمارة
# Original road count: داذان
# Original road count: الهدار
# Original road count: قاسم بن عبدالله
# Original road count: شارع محمد المحتسب
# Original road count: مسلم بن مجفل السبيعي
# Original road count: Al Jabrah
# Original road count: أم الغدف
# Original road count: علاج بن عمرو
# Original road count: حائل
# Original road count: إسماعيل الأزهري
# Original road count: عبدالجليل الأوسي
# Original road count: الأحقاف
# Original road count: ابن مهنا
# Original road count: أسعد بن سلامة الأنصاري
# Original road count: زينب بنت الحافظ الطبرية
# Original road count: صالح القاضي
# Original road count: أبي عويدين
# Original road count: جبل النير
# Original road count: قصوان
# Original road count: رقم 433
# Original road count: جبل العمور
# Original road count: شريح بن عبيد
# Original road count: الليث
# Original road count: اليعقوبي
# Original road count: Al Athra
# Original road count: ممر بركة بن نزار
# Original road count: شارع أبي العز الأثيري
# Original road count: عمر السلمي
# Original road count: 6009
# Original road count: ربيق
# Original road count: Asir
# Original road count: ممر65
# Original road count: جبل أبان
# Original road count: الدميري
# Original road count: شارع هشام بن عبدالملك
# Original road count: عيسى بن أوس
# Original road count: يوسف بن عيسى
# Original road count: محمد بن عبدالرزاق حمزة
# Original road count: Alsafa
# Original road count: البريمي
# Original road count: محمد الزناتي
# Original road count: آشور
# Original road count: الظهيره
# Original road count: الملاح
# Original road count: عبدالله السديس
# Original road count: روضة الأجداد
# Original road count: المنذر بن الطفيل
# Original road count: شارع حجاب الدولي
# Original road count: Al Bejadiya
# Original road count: أحمد بن حبان
# Original road count: خالد بن زيد
# Original road count: Al Henka
# Original road count: أربل
# Original road count: غلام الخزانة
# Original road count: أبي الوليد بن زيدون
# Original road count: أريمة
# Original road count: الشهاب الطيب
# Original road count: 45
# Original road count: شارع دومة الجندل
# Original road count: Hashim Bin Ajera
# Original road count: فؤاد سزكين
# Original road count: رشيد الشهاب
# Original road count: علي بن عبدالله بن عبدالشكور
# Original road count: جلال الدين بن محمد الطبري
# Original road count: عماد الدين زنكي
# Original road count: شارع قلعة صلاح الدين
# Original road count: مغيرة
# Original road count: عيسى الخياط
# Original road count: ابي ابراهيم البرداني
# Original road count: Ariha
# Original road count: حبان بن منقذ
# Original road count: ابن أبي بكر
# Original road count: تلمسان
# Original road count: شارع ابن قاضي
# Original road count: شارع الأحجر
# Original road count: Arbil
# Original road count: Al Fayadhah
# Original road count: الغرابي
# Original road count: ريلاء
# Original road count: شارع تامور
# Original road count: تميم بن مقبل
# Original road count: Al Hayaniya
# Original road count: الأمصار
# Original road count: عنك البكرات
# Original road count: العلاء بن الحضرمي
# Original road count: أبي الشكر البلخي
# Original road count: أحمد البرادعي
# Original road count: الخطاب بن نفيل
# Original road count: إسماعيل بن المظفر
# Original road count: شارع المهلب بن صفرة
# Original road count: شارع التاج
# Original road count: شارع أبي بكر الخوارزمي
# Original road count: شارع ابن القصيرة
# Original road count: مقاتل بن سليمان
# Original road count: ال مقحم
# Original road count: القطار
# Original road count: عبدالله بن المزربان
# Original road count: يحيى النجار
# Original road count: سالم العطاس
# Original road count: المؤيد التكريتي
# Original road count: شارع أحمد اليزيدي
# Original road count: الكوفة
# Original road count: السامري
# Original road count: شارع الحاتمية
# Original road count: سعيد بن عثمان
# Original road count: جبل الفاو
# Original road count: شارع أبي الشكر الصابوني
# Original road count: سماك بن حرب
# Original road count: بلقيس
# Original road count: ممر القاربة
# Original road count: الزرنوقة
# Original road count: أبي طاهر المقدسي
# Original road count: شارع احمد ناضرين
# Original road count: وادي مأرب
# Original road count: شارع عبدالعزيز القبيطي
# Original road count: أثيب
# Original road count: خلاد بن رافع
# Original road count: أبي جعفر بن رزيق
# Original road count: العرار
# Original road count: أسيلة
# Original road count: جابر بن مسلم
# Original road count: زهير البلوي
# Original road count: Obalda Bin Rabiea
# Original road count: محمد بن الذهبي
# Original road count: Mahmud Zenki
# Original road count: Abu Arab Valley
# Original road count: النسري
# Original road count: وادي حدلي
# Original road count: ممر107
# Original road count: إبراهيم بن أبي بكر الطبري
# Original road count: Al Jamuh Al Ansarii Street
# Original road count: 70th Street
# Original road count: اللسيب
# Original road count: الشروطي
# Original road count: الغروب
# Original road count: رميثان
# Original road count: شارع عتيك بن قيس
# Original road count: ابن ملاح الشط
# Original road count: إبراهيم بن أحمد بن عبدالكافي
# Original road count: الطفيل بن زيد
# Original road count: تركي بن حميد
# Original road count: الحفائر
# Original road count: Safages
# Original road count: هبة الله الطيبي
# Original road count: ممر يحيى بن أسيد الأنصاري
# Original road count: شارع عمرو بن نصر
# Original road count: خطيب مشكان
# Original road count: السبيحة
# Original road count: ابن زيادة
# Original road count: إسماعيل بن عبدالملك
# Original road count: شارع القمراء
# Original road count: محمد فدا
# Original road count: الشيخ خليل
# Original road count: زهير رستمزهير رستم
# Original road count: مجد الدين
# Original road count: Al Bazan
# Original road count: رمان
# Original road count: الحشرج
# Original road count: ابن أكثم
# Original road count: ابن الحبيق
# Original road count: أحمد بن فارس
# Original road count: عبدالمحسن المنيع
# Original road count: طريق عقلة الغويري - القرين
# Original road count: شارع ابيض بن اسود
# Original road count: Al-Wafaq
# Original road count: الوصابي
# Original road count: وادي جيزان
# Original road count: قبلي
# Original road count: قيس بن عاصم
# Original road count: كيفان
# Original road count: ممر ابوقتاده بن ريعي الانصاري
# Original road count: الجهاد
# Original road count: الشطرة
# Original road count: Al Ebeila
# Original road count: البساتين
# Original road count: أمة الرحمن
# Original road count: علي الربيش
# Original road count: أحمد بن نافع
# Original road count: شارع عدي بن طلحة
# Original road count: محمد بن تمليخ
# Original road count: جليلة
# Original road count: أحمد بن مطرف
# Original road count: شارع علي الظاهري
# Original road count: صداء
# Original road count: أبي محمد النميري
# Original road count: no. 21
# Original road count: القيصوم
# Original road count: الظهرين
# Original road count: شارع عائذ بن سعيد
# Original road count: يحيى عوض القحطاني
# Original road count: أسد بن عمرو
# Original road count: Khafaf Al Tamimi
# Original road count: هشام بن بشير
# Original road count: أبي المجد الشنائي
# Original road count: سبط العفيف
# Original road count: شمس الدين الخوارزمي
# Original road count: التريكي
# Original road count: سيهات
# Original road count: Rashed Bin Kaneeni
# Original road count: عبدالغني بن سلام
# Original road count: أحمد العباسي
# Original road count: الجادعي
# Original road count: أبي واقد الليثي
# Original road count: زين العابدين المنوفي
# Original road count: Radwa
# Original road count: شارع أبي مدين الزعفراني
# Original road count: رضية
# Original road count: Al Abbas Al Rashidi St.
# Original road count: خبيب بن يساف
# Original road count: Imam Abdulrahman Al Faisal
# Original road count: روضة النور
# Original road count: عبدالرحمن بن هبة الله
# Original road count: Zainab Al Thaqafiyah
# Original road count: أبي العباس الكاملي
# Original road count: الفرعية
# Original road count: شارع معروف بن أبي الفتح
# Original road count: عاقل الليثي
# Original road count: بني سعد
# Original road count: أبي بكر الحلواني
# Original road count: شارع التنسيق
# Original road count: زامل بن سليم
# Original road count: الأبواء
# Original road count: Al Jeishi
# Original road count: شارع جبل براك
# Original road count: أحمد بن النفيس
# Original road count: التوبات
# Original road count: أبي يحيى الأصولي
# Original road count: شارع الزريقات
# Original road count: الأشعري
# Original road count: الرقية
# Original road count: شارع حصن بن وبرة الطائي
# Original road count: الحريق _ الرين
# Original road count: الأسياح
# Original road count: وادي بيش
# Original road count: قوز الشريف
# Original road count: عبدالرحمن الدوسري
# Original road count: أسلم الأندلسي
# Original road count: محمد آل قاسم
# Original road count: علان القيسي
# Original road count: كريم الدين البرموني
# Original road count: شارع ناصر الدين
# Original road count: محمد بن سعد بن حسين
# Original road count: جبل الريث
# Original road count: الحسن الزعفراني
# Original road count: صفاقس
# Original road count: الوجيف
# Original road count: Al Saeed Al Sanwse Altarbesi
# Original road count: العيلاني
# Original road count: حسين الديار بكري
# Original road count: شارع الخاصرة
# Original road count: سلمان الراذاني
# Original road count: حويمضة
# Original road count: ناصر بن شامان
# Original road count: صالح الجيلي
# Original road count: عبدالحق السهمي
# Original road count: عبدالله الشيبي
# Original road count: المضايا
# Original road count: عبدالملك بن العباس
# Original road count: ابن نجيب
# Original road count: زخو
# Original road count: تميم الربعي
# Original road count: طريق رماح - القليب الونان الصرار النعيرية
# Original road count: 'Al Shaqraa
# Original road count: الطائرة
# Original road count: زيد بن صوحان
# Original road count: المرصفي
# Original road count: شارع صالح بن احمد الحلبي
# Original road count: أبي طالب التميمي
# Original road count: ابن الربيع
# Original road count: ممر القطيفة
# Original road count: الشحانية
# Original road count: An Balالنبل
# Original road count: No.40
# Original road count: شارع مكة المكرمة
# Original road count: أحمد الشامي
# Original road count: محمد بن أحمد القسطلاني
# Original road count: الكايا
# Original road count: شارع ابن عميرة المخزومي
# Original road count: وادي المعيدن
# Original road count: شارع ابراهيم بن عبدالمحسن السلطان
# Original road count: Al Omq
# Original road count: الحكم بن عمرو
# Original road count: الأوشح
# Original road count: ممر ضاحك
# Original road count: الملك فهد فرعي
# Original road count: عبدالله بن قتادة
# Original road count: حسين الغيثي
# Original road count: الجراح الحكمي
# Original road count: شارع ابن تيمية
# Original road count: الصدق
# Original road count: شارع جبل نمرة
# Original road count: Al Qadi Abu Altaeb
# Original road count: محمد بن صاعد
# Original road count: Mohammed Bin Shlhob
# Original road count: جبل اروم
# Original road count: Wadi Ash Shuhada
# Original road count: شارع الرويضة
# Original road count: باجل
# Original road count: عبيدالله الثقفي
# Original road count: ابن المهندس
# Original road count: الشعابات
# Original road count: يحيى المخزومي
# Original road count: Ibn Khalkan
# Original road count: أبي محمد الضياء
# Original road count: خرزة
# Original road count: بير الخيام
# Original road count: البدر العيني
# Original road count: Nasser Bin Ammar
# Original road count: Alkotieb
# Original road count: عبدالقادر الدميري
# Original road count: جمال الدين بن المكرم
# Original road count: ابي الحسن المقدسي
# Original road count: رابعة بنت ثابت
# Original road count: عذبة
# Original road count: الرشين
# Original road count: الأمير عبدالرحمن بن سعود بن عبدالعزيز
# Original road count: الدحيقي
# Original road count: حسن عباس شربتلي
# Original road count: علي بن سليم
# Original road count: No. 281
# Original road count: يحيى العداواني
# Original road count: علي بن يوسف
# Original road count: الديوان
# Original road count: الدفرة
# Original road count: رآمة
# Original road count: عاقل بن حبيب
# Original road count: هشام بن معاوية
# Original road count: Ras Al Sirr
# Original road count: المحياة
# Original road count: نهر الفضل
# Original road count: Dherar Bin Al Khattab
# Original road count: طريق الأمير سطام بن عبدالعزيز
# Original road count: شارع ابن أبي المختار
# Original road count: الرشيدي
# Original road count: خالد السدوسي
# Original road count: شارع جرول بن عباس
# Original road count: شارع 178
# Original road count: شارع حسن الإسكندراني
# Original road count: الأشبوني
# Original road count: عنبسة الغافقي
# Original road count: الحاكم بأمرالله
# Original road count: ابن النفيس الرميلي
# Original road count: Mumar1
# Original road count: كرمة
# Original road count: Abi Abdullah Al Safali
# Original road count: طريق عقلة الغويري - مصدة
# Original road count: شارع اللاذقية
# Original road count: المحراك
# Original road count: الصيحان
# Original road count: ممر مؤتة
# Original road count: Al Namrin Path
# Original road count: هارون بن جعفر
# Original road count: أبي المنصور البغدادي
# Original road count: شارع جبل الأجداد
# Original road count: المخيريم
# Original road count: حرة الحجرة
# Original road count: الشيحية
# Original road count: الصدر
# Original road count: أمين بن حسن الميرغني
# Original road count: ابن اللبان
# Original road count: مهدي المصلح
# Original road count: شارع أبي قبيس
# Original road count: علي بن حسان
# Original road count: رقم 221
# Original road count: الثامية
# Original road count: سواد بن قارب
# Original road count: النعمان الواسطي
# Original road count: شارع تميم بن المعز
# Original road count: رهيشة
# Original road count: أبي الحمناء العنبري
# Original road count: فضيلة السيد محمد حسين افندي
# Original road count: علي بن فرحون
# Original road count: الأمير سعود بن فيصل بن عبدالعزيز
# Original road count: Al Dabi'A
# Original road count: أم حبيبة بنت أبي سفيان
# Original road count: ابن شبة
# Original road count: بشر بن سعيد
# Original road count: الطريق الدائري الثاني
# Original road count: ابن الحسين النعماني
# Original road count: الجحاف بن حكيم السلمي
# Original road count: المشاهير
# Original road count: وادي الجوف
# Original road count: أحمد بن صفوان
# Original road count: النبقية
# Original road count: Al Damor
# Original road count: النوارس
# Original road count: شارع جبل الأبره
# Original road count: Al Anadhol
# Original road count: ابن سند البصري
# Original road count: سويد الأنصاري
# Original road count: تنمة
# Original road count: الملعب
# Original road count: الترنج
# Original road count: الكواكب
# Original road count: تاج
# Original road count: No. 355
# Original road count: Al Jobeir
# Original road count: Prince Turkey Bin Abdul Aziz Al thani
# Original road count: أبي عبيد الهروي
# Original road count: بركة
# Original road count: ممر  أحمر بن قطن الهمداني
# Original road count: مدينة الخبرا
# Original road count: النجيل
# Original road count: أبي العتاهية
# Original road count: سرة
# Original road count: وادي الأحمر
# Original road count: شارع الحارث بن تبيع الرعيني
# Original road count: النفل
# Original road count: Al Jawafa2
# Original road count: Al Noweiba
# Original road count: محمد عبدالله السبيعي
# Original road count: Jabr Ibn Rashid
# Original road count: محاسن البغدادي
# Original road count: Al Sadar
# Original road count: إبراهيم بن أبي الشكر
# Original road count: داود بن الهيثم
# Original road count: الأبرار
# Original road count: Al Imam Abdullah Bin Saud Bin Abdulaziz
# Original road count: عبدالملك العصامي
# Original road count: ممر رزين بن عماد
# Original road count: يوسف بن المطهر
# Original road count: عامر بن أبي ربيعة
# Original road count: عبدالعزيز بن غريب
# Original road count: أيمن بن نائل
# Original road count: الانتفاضة
# Original road count: Abdullah Bin Yahya
# Original road count: أوس العامري
# Original road count: ربيعة التجيبي
# Original road count: الظهرانية
# Original road count: عمودان
# Original road count: سعيد بن أبي سعد
# Original road count: المزار
# Original road count: ابن العماد الحنبلي
# Original road count: صالح محمد الحسني
# Original road count: Alhassan
# Original road count: أبي أحمد القيسي
# Original road count: أبي عبدالملك الثقفي
# Original road count: 333
# Original road count: أبي ربيعة الربعي
# Original road count: ممر يحيى الكوفي
# Original road count: الأشقر
# Original road count: شارع أحمد البسطامي
# Original road count: أم يونس
# Original road count: Al Khamadin
# Original road count: كمال الدين الفارسي
# Original road count: الوطن
# Original road count: ضريبة
# Original road count: عين نوباء
# Original road count: شارع الزكية
# Original road count: شارع الأمن
# Original road count: دوينة
# Original road count: Al Jondob
# Original road count: محمد شاذلي
# Original road count: Al Saqr
# Original road count: بلطة
# Original road count: محمد السدوسي
# Original road count: الذهيبات
# Original road count: شارع ذو المعالي
# Original road count: عمرو بن حنظلة
# Original road count: شارع قبيبان
# Original road count: سعد بن بخيت التركي
# Original road count: الشهاب الجازاني
# Original road count: حريث بن عمار
# Original road count: وادي هجر
# Original road count: الطالعة
# Original road count: أم العطا
# Original road count: Abu Bakar As-Sudiq Road
# Original road count: أم راكة
# Original road count: الشهمة
# Original road count: الفزير
# Original road count: علي بن يعيش
# Original road count: سهيل بن رافع
# Original road count: الأميرة طرفه بنت الإمام
# Original road count: فرحة
# Original road count: الثعلبي
# Original road count: شهاب الدين الدمنهوري
# Original road count: أبي النجح إسماعيل
# Original road count: عريفجان
# Original road count: علي بن أبي عمرو
# Original road count: الخليفة الأمين
# Original road count: نزهون الغرناطية
# Original road count: ابن البحري
# Original road count: الحسن الخطير
# Original road count: سليمان السلمي
# Original road count: بطحان
# Original road count: عقبة بن عامر
# Original road count: سعد الكندي
# Original road count: الصائن
# Original road count: العباس بن عبدالمطلب
# Original road count: no.188
# Original road count: Aal Jouda
# Original road count: عثمان عبدالكريم العبيداء
# Original road count: الشجوة
# Original road count: مصطفى كامل
# Original road count: Adrar
# Original road count: البقاعي
# Original road count: بدن بن زيد الدوسري
# Original road count: حطان بن عوف
# Original road count: الأمير أحمد بن عبدالرحمن بن فيصل
# Original road count: سهل بن عتيك
# Original road count: السليم
# Original road count: No. 114
# Original road count: عكرمة الهاشمي
# Original road count: شارع سعد بن معاذ
# Original road count: بدائع المستجدة
# Original road count: King Salman Road
# Original road count: ضمد
# Original road count: عبدالجليل بن عبدالواسع
# Original road count: رماح
# Original road count: سيئون
# Original road count: بشير بن محفوظ
# Original road count: جعفر بن شاكر
# Original road count: بكر بن النطاح
# Original road count: غازي
# Original road count: عبدالسلام بن أبي إسحاق
# Original road count: الشاهق
# Original road count: المسراب
# Original road count: أم عبدالرحمن الصالحي
# Original road count: نمران
# Original road count: أبي الفتوح الخطيب
# Original road count: أبي إسحاق الأبناسي
# Original road count: شارع علي العدوي
# Original road count: عين صالح
# Original road count: الحارث بن حاطب الجمحي
# Original road count: شارع ساجر
# Original road count: ابن الحافظ
# Original road count: عاصم بن حميد السكوني
# Original road count: ابراهيم القرماني
# Original road count: الابردان
# Original road count: أم شيحة
# Original road count: سعيد بن المبارك
# Original road count: زكريا بن يحيى
# Original road count: سديرة
# Original road count: Obaidallah Bin Abdulwadood
# Original road count: الوسيعة
# Original road count: هدى الشام
# Original road count: شارع وادي غليل
# Original road count: شارع عبدالله بن عمر بن العاص
# Original road count: شارع أريحا
# Original road count: ممر ابن أبي العلاء
# Original road count: نبيل عبدالله رياني
# Original road count: شارع همام بن المهذب
# Original road count: ربيعة الرائي
# Original road count: الهلالية
# Original road count: الغيل
# Original road count: سحام
# Original road count: Nemran
# Original road count: أبي الفتوح المسمعي
# Original road count: Al Alaa Bin Zyadh
# Original road count: Al Kawthar
# Original road count: شارع يوسف بن عبدالله بن سلام
# Original road count: غانم المخزومي
# Original road count: عبدالله بن الجد السلمي
# Original road count: Ibraheem Al Harwe
# Original road count: فيفاء
# Original road count: رأس الجرة
# Original road count: جعفر بن أبي طالب
# Original road count: زنجبار
# Original road count: إبراهيم بن مخلد
# Original road count: الحنكة
# Original road count: أبي الجهم العدوي
# Original road count: Al Qadhi St.
# Original road count: العويتة
# Original road count: الدائري الثاني
# Original road count: البشائر
# Original road count: ابن نصر
# Original road count: أبي إسلام
# Original road count: الحلقي
# Original road count: أبي الشمقمق
# Original road count: شرفة
# Original road count: شارع تطوان
# Original road count: Al Qatadah
# Original road count: علي بن يحيى الحافظ
# Original road count: الحازة
# Original road count: عبدالله بن أيوب
# Original road count: جبل ودان
# Original road count: طريق العبدلي
# Original road count: زياد بن سعد
# Original road count: قرحه
# Original road count: Al Azhar
# Original road count: المنذر بن وبرة
# Original road count: الأشرفية
# Original road count: Al Mofasser
# Original road count: عبدالوهاب البغدادي
# Original road count: شارع عين ابن فهيد
# Original road count: ابن زيدان
# Original road count: أبي سلمة الهلالي
# Original road count: Western Ring Rd
# Original road count: Al Badi' Al Janoubi
# Original road count: الشيخ سعد بن محمد آل حسين
# Original road count: موسى بن مقيبل بن عوض العتيبي
# Original road count: حميان
# Original road count: رافع بن المعلي
# Original road count: حنبل بن إسحاق
# Original road count: رقم 89
# Original road count: شارع رقم 378
# Original road count: أبي الكرم
# Original road count: Hamad Bin Zaid
# Original road count: الأسد
# Original road count: Horan
# Original road count: Mohammed Al Robee
# Original road count: حامد أزهر
# Original road count: الحجاج بن أيمن بن عبيد
# Original road count: Al Dhalea
# Original road count: شارع الراعي الكبلي
# Original road count: شارع نجم الانصاري
# Original road count: عبدالعزيز النمراوي
# Original road count: الحسن بن دلال
# Original road count: جبل المشايخ
# Original road count: العرويشة
# Original road count: شارع عمرو بن عبيد
# Original road count: عاصم بن الخطاب
# Original road count: Abu Manjal
# Original road count: البيداء
# Original road count: المرار بن بشير
# Original road count: أبي القاسم النجيب
# Original road count: أبان بن صالح
# Original road count: أبي سعيد الأصطرخي
# Original road count: الطرماح بن حكيم
# Original road count: صفصاف
# Original road count: طبابه
# Original road count: سيحون
# Original road count: شارع الصنعاني
# Original road count: حسين ميراز
# Original road count: ممر مبارك الدويك
# Original road count: سفيان بن قيس
# Original road count: Al Tamimi Mosque
# Original road count: Al Qartalbi
# Original road count: الصحوة
# Original road count: شارع ابن سفير
# Original road count: 33
# Original road count: أحمد حمودة
# Original road count: البقيع
# Original road count: يونس بن عمر
# Original road count: شارع محمد التمار
# Original road count: شارع يحيى أبي طالب
# Original road count: واثلة بن الأسقع
# Original road count: Ismail Al Andulus
# Original road count: شارع محمد بن أبي البركات
# Original road count: شارع وداعة بن ابي وداعة
# Original road count: ابن الزبير
# Original road count: Al Yasr
# Original road count: نسيب عريضة
# Original road count: شارع دهيم
# Original road count: Al-Makla
# Original road count: الدخن
# Original road count: شارع منجد
# Original road count: Salih Bin Abbas
# Original road count: العطفان
# Original road count: Ibn Taymeeyah Road
# Original road count: أم الورود
# Original road count: طرابيل
# Original road count: Janada Bin Malik
# Original road count: السدود
# Original road count: الملك محمد الخامس
# Original road count: عبدالله بن حسن بيلا
# Original road count: حمزة الاركوبي
# Original road count: حجيلاء
# Original road count: حذيفة بن اليمان
# Original road count: طريق سبت العلاية
# Original road count: Hamza Bin Abdulmuttallib
# Original road count: برجان
# Original road count: زهرة بنت أبي محمد
# Original road count: Al Talha
# Original road count: شعيب الدارة
# Original road count: 64
# Original road count: قلعة أيوب
# Original road count: رأس الجزاير
# Original road count: طريق الخميس السليل
# Original road count: حاند بن اسماعيل
# Original road count: طريق الدائري الشرقي -الثوير
# Original road count: أبي الدر الرومي
# Original road count: بحيرة دمياط
# Original road count: ممر الزين
# Original road count: الأمير فهد بن سعد بن عبدالرحمن
# Original road count: ابن أبي العافية
# Original road count: الذهبي
# Original road count: العمور
# Original road count: بشري الجبرتي الشافعي
# Original road count: طريق مزارع
# Original road count: أبي تميم حيدرا
# Original road count: عبدالرزاق بن يحيى
# Original road count: Jalilia
# Original road count: شرف الدين المصري
# Original road count: Abi Taher Ibn Al Salam
# Original road count: الكتيفة
# Original road count: عامر البكري
# Original road count: المانع
# Original road count: ابن ميسر
# Original road count: شارع بهير الحارثي
# Original road count: قصي بن كلاب
# Original road count: No. 277
# Original road count: Omar Al Hajeb
# Original road count: بير سلمان
# Original road count: سليمان المحاسني
# Original road count: البصيصة
# Original road count: الرجيمة
# Original road count: Thadeq
# Original road count: آل عواد
# Original road count: Al Harjalah Valley
# Original road count: Abu Thabit
# Original road count: محمد ناصر الحمود
# Original road count: Ghazala
# Original road count: أبي منصور الطبري
# Original road count: سعيد بن العاصي
# Original road count: الشويهات
# Original road count: نصر بن مزاحم
# Original road count: علي بن بسام الشنتريني
# Original road count: AL Habaq
# Original road count: أبان بن تغلب
# Original road count: 5044
# Original road count: أم برقة
# Original road count: فاطمة بنت أسد
# Original road count: الدار الحمراء
# Original road count: شارع الواديان
# Original road count: المقرئ الصقلي
# ...
# Original road count: Ahmed bin Alsaqr
# Original road count: Shaheed Al Din Thum Al Watan Ibrahim Ali Al Qarni
# Original road count: ممر سالم مولى أبي حذيفة
# Original road count: الإنشراح
# Original road count: خليل بن قلاوون الصالحي
# Original road count: طحاحين
# Original road count: علاء الدين الأنصاري
# Original road count: حاطب الأسدي
# Original road count: الثوده
# Original road count: Prince Turki Ibn Abdulaziz-Senior Road
# Original road count: تقي الدين بن عمر الزرعة
# Original road count: الكلاعي
# Original road count: زين الدار المصري
# Original road count: كندة بن هذيم
# Original road count: شارع شنقيط
# Original road count: سعد بن أبي وقاص
# Original road count: غزة
# Original road count: ممر مليل بن وبرة
# Original road count: أبي داود بن إياد
# Original road count: منفوحة
# Original road count: يحيى بن قاسم
# Original road count: محمد بن فهد المكي
# Original road count: شارع أبي منصور الكوفي
# Original road count: Koalalampour
# Original road count: الازاهي
# Original road count: صالح بن محمد المصيبيح
# Original road count: الثامات
# Original road count: عبدالله بن محمد بن المهندس
# Original road count: 7
# Original road count: Ali Bin Abi Al Saadat
# Original road count: جبل المهد
# Original road count: Omaya Ibn Yazid
# Original road count: شارع الغيلانة
# Original road count: عرب المراسي
# Original road count: Jouda
# Original road count: أبي إسحاق الشيرازي
# Original road count: الدمشقي
# Original road count: الغور
# Original road count: بردي
# Original road count: ابي القاسم بن مسعود
# Original road count: جدرة
# Original road count: أحمد بن عمر الخصاف
# Original road count: سليمان بن عبدالله آل الشيخ
# Original road count: خشيبة
# Original road count: أبي نزار الجمال
# Original road count: عامر بن كندة
# Original road count: عرابة الأوسي
# Original road count: أبي زيد الأسدي
# Original road count: حصن عاصم
# Original road count: إبراهيم بن مرزوق
# Original road count: ملل الشمالي
# Original road count: قصر الأزرق
# Original road count: البيئة
# Original road count: البراك
# Original road count: ممر أبو عنابة
# Original road count: علي البجادي
# Original road count: طريق الرياض - حوطة بني تميم
# Original road count: خديجة بنت حسان
# Original road count: شارع معاذ بن الحارث الارقم
# Original road count: الخطية
# Original road count: عبدالوهاب بن إبراهيم الزنجاني
# Original road count: شارع خالد الفرح
# Original road count: Fehad Al-gahtani
# Original road count: الحاسب الغرناطي
# Original road count: متعب الثقفي
# Original road count: Jafar Bin Ahmad
# Original road count: Al Areen
# Original road count: شارع الحسن بن عبدوس
# Original road count: Ali Bin Al Khasib
# Original road count: هدبة بن مصعب
# Original road count: وجية الشحامي
# Original road count: رأس أبي الموج
# Original road count: ممر18
# Original road count: الحسين التاج
# Original road count: عبدالحميد الكاتب
# Original road count: هروب
# Original road count: شارع سليمان احمد فقية
# Original road count: Ibn Kaseer
# Original road count: مالك بن المزموم
# Original road count: Ibn Khaldoum
# Original road count: شعيب العصمة
# Original road count: منذر التجيبي
# Original road count: حسين علي الزبادين
# Original road count: حرض
# Original road count: ثوال
# Original road count: بقيق
# Original road count: الزين السنبكي
# Original road count: إحجار الثمام
# Original road count: السلطان عبدالحميد
# Original road count: يوسف الدباس
# Original road count: شارع عبدالله بن حسين ال الشيخ
# Original road count: سلمى بن نوفل
# Original road count: شداد بن أوس
# Original road count: 137
# Original road count: Soliman Al Belouwi
# Original road count: الحسن بن شجاع
# Original road count: مدركة
# Original road count: Naq'A
# Original road count: عبدالله بن الحسن القرطبي
# Original road count: عمرو بن النبيت
# Original road count: المكتبة
# Original road count: ذهيلة
# Original road count: عكيلة
# Original road count: آل طالب
# Original road count: 31
# Original road count: خب الصقرات
# Original road count: الشيخ عبدالرحمن القحطاني
# Original road count: ابن طولون
# Original road count: ثادق
# Original road count: طريق طلحة بن عبيدالله
# Original road count: ممر المرقب
# Original road count: أرمنت
# Original road count: Abi Al Hussein Al Azdi
# Original road count: الجوهرة بنت بن معمر
# Original road count: Yousaf Al Sanbalwani
# Original road count: شارع البرتقال
# Original road count: أذربيجان
# Original road count: قطرب
# Original road count: هجرة السلات
# Original road count: ابن البياز
# Original road count: 177
# Original road count: صالح بن عبدالقدوس
# Original road count: Radhi
# Original road count: حسن الشاعر
# Original road count: محمد بن عبدالأعلى
# Original road count: محمد بن ورقاء
# Original road count: عباد الناجي
# Original road count: المرازيق
# Original road count: ابن غسان
# Original road count: إبان بن عثمان
# Original road count: Khalid Bin Ibida
# Original road count: مرثد اليزني
# Original road count: Al Afrah
# Original road count: رشدي العظمة
# Original road count: علي بن الحسن الريحاني
# Original road count: الصحيفات
# Original road count: ريع المطرة
# Original road count: البهاء زهير
# Original road count: شارع ضياء الدين المقدسي
# Original road count: حصن مهدي
# Original road count: سعد الله بن مجالد
# Original road count: عسير
# Original road count: عبدالله الدينوري
# Original road count: شارع بدر ابن مسعد
# Original road count: الزبيدي
# Original road count: الأمير التنوخي
# Original road count: no.55
# Original road count: عدي بن نوفل
# Original road count: Abdul Rahman Abi Al Fadhl
# Original road count: حضوة
# Original road count: شارع يحي بن نفير
# Original road count: سليمان بن عبدالملك بن مروان
# Original road count: Alathel
# Original road count: محمد علي جناح
# Original road count: غالية البقمية
# Original road count: مرسي علم
# Original road count: الزعيمي
# Original road count: Al Massaif
# Original road count: شارع شويكة
# Original road count: ابن جهير البغدادي
# Original road count: يميل بن دهناء
# Original road count: حسن سعيد المخرج
# Original road count: Diba
# Original road count: الظميران
# Original road count: البحر الأسود
# Original road count: عبدالله بن حماد الشبيلي
# Original road count: Gate-5 (Entrance)
# Original road count: أحمد شفيق
# Original road count: الأرز
# Original road count: الحصنين
# Original road count: بير الزبارة
# Original road count: شارع فهد الباهلي
# Original road count: بكر صباغ الشافعي
# Original road count: المبارك بن سلمان
# Original road count: أم ردمة
# Original road count: أحمد بن الأزرق
# Original road count: Al Jasar
# Original road count: شهيد الدين ثم الوطن عبدالرحمن سعيد عبدالرحمن الشهراني
# Original road count: شارع عمر بن فهد المكي
# Original road count: النبراس
# Original road count: عثمان بن الحويرث
# Original road count: محمد بن علي بن فضل الطبري
# Original road count: Al Zoreiqat
# Original road count: مرج العيون
# Original road count: Ibn Al Mothfer Al Hatemi
# Original road count: عادر
# Original road count: ممر السدر
# Original road count: شارع وادي فحيه
# Original road count: 58
# Original road count: إسماعيل بن الأشعث
# Original road count: هشام بن إبراهيم الأنصاري
# Original road count: Al Fostoq
# Original road count: السهول
# Original road count: محمد الرياشي
# Original road count: Al Hulayfah
# Original road count: طريق بدائع القرارة
# Original road count: Raida
# Original road count: خير الدين الأيوبي
# Original road count: الياقوت
# Original road count: القياس
# Original road count: شارع عبدالرحمن أبي شامة
# Original road count: العاصي
# Original road count: مجصة
# Original road count: وادي الجناح
# Original road count: Beasha Valley
# Original road count: لاعس
# Original road count: الطائر الزيتي
# Original road count: Salma Bin Omer
# Original road count: الفرش
# Original road count: شارع توفيق طارق
# Original road count: شارع يزيد بن الاسود الكندي
# Original road count: آل صفيان
# Original road count: مكحول الشامي
# Original road count: الحارث بن شريح
# Original road count: يحيى المشيرقي
# Original road count: الشواليب
# Original road count: مهيفة
# Original road count: عثمان بن بشر
# Original road count: صالح الهاشمي
# Original road count: الحصين بن حمام المري
# Original road count: ضاحية
# Original road count: حمد بن لعبون
# Original road count: رجاء بن أبي رجاء
# Original road count: علي بن الخلال
# Original road count: شارع داود بن عمر
# Original road count: شارع علقان
# Original road count: الأنباري
# Original road count: يعقوب بن الربيع
# Original road count: البدليس
# Original road count: الجزْعة
# Original road count: رأس حرجل
# Original road count: الخادر
# Original road count: شارع كعب بن حذيفة
# Original road count: القاضي الجلابي
# Original road count: مقبولة
# Original road count: أم النعسان
# Original road count: 308
# Original road count: Abdulaziz Al Nashmi
# Original road count: يوسف أحمد
# Original road count: Al Tirmizi
# Original road count: ممر زياد الفزاري
# Original road count: أبي الصواني
# Original road count: الحمط
# Original road count: قلعة المدق
# Original road count: لغدان
# Original road count: علي بن القاسم القاشاني
# Original road count: أبي صالح المكي
# Original road count: الشيخ راشد بن عبيد القرون
# Original road count: تميم بن أبي بكر
# Original road count: الكردوس بن المنيع
# Original road count: Ein Al Ramma
# Original road count: عين هيت
# Original road count: الحسين بن عثمان الحربي
# Original road count: اسحاق بن بشر البخاري
# Original road count: حرملة بن يحيى
# Original road count: علي بن خلف الأنصاري
# Original road count: محمد سعيد قدسي
# Original road count: شارع الرهط
# Original road count: Al Termithi
# Original road count: طريق دقلة - ملهم
# Original road count: عبدالله صنات براك المرشدي
# Original road count: آل عساكر
# Original road count: دهوك
# Original road count: المنحل العنبري
# Original road count: أبي ظهير العصيمي
# Original road count: Zoubeid Valley
# Original road count: Hagel
# Original road count: مدرك بن حصن
# Original road count: قلعة خاصبه
# Original road count: مصباح المالكي
# Original road count: النزلة الشرقية
# Original road count: Al Difa
# Original road count: أحمد صالح المري
# Original road count: حيان مولى قريش
# Original road count: السمح بن مالك
# Original road count: مرقان
# Original road count: Qotaiban
# Original road count: واصل
# Original road count: جبل حضن
# Original road count: أبي سليك
# Original road count: Ibn Khaishala
# Original road count: السحيمي
# Original road count: أبي القزاز
# Original road count: وثيث
# Original road count: ممر الشبول
# Original road count: شارع ابن حوقل
# Original road count: حمد بن إبراهيم آل داوود
# Original road count: الحجاج الفهري
# Original road count: Jarir
# Original road count: عبدالواحد بن عبدالسلام
# Original road count: ربلاء
# Original road count: الغزيز
# Original road count: ابن المؤيد
# Original road count: حسن شاكر أفلاطون
# Original road count: أحمد الفيض آبادي
# Original road count: عروة بن عياض بن عدي النوفلي
# Original road count: غرس الدين الأشقر
# Original road count: Khalij Adan
# Original road count: ابن تقي
# Original road count: Al-Khansa
# Original road count: الكهف
# Original road count: عطارة
# Original road count: طريق القرارة
# Original road count: أم عمارة
# Original road count: قندهار
# Original road count: جبل الكرمل
# Original road count: جبل الجزيرة
# Original road count: 152
# Original road count: Ali Bin Hassan
# Original road count: شارع واقد مولى رسول الاسلام
# Original road count: يونس بن يحيى
# Original road count: ثمينة
# Original road count: Abdullah Bin Abi Habeeb
# Original road count: شارع يوسف القرشي
# Original road count: طريق جلاجل
# Original road count: يعقوب بن غنائم
# Original road count: Al Sarqasti
# Original road count: Al Nafisan
# Original road count: الدباس
# Original road count: ممر الأصوف
# Original road count: راشد الجيبا
# Original road count: شارع غنيمة
# Original road count: شارع ثعلبة بن سعد الخزرجي
# Original road count: قلعة صنعاء
# Original road count: As Sil Kabeer
# Original road count: الرحيبات
# Original road count: Mohammed Ali Alqahtany
# Original road count: فرج حسين
# Original road count: صالح الكراني
# Original road count: ميسان
# Original road count: عبدالرحمن بن ثابت بن الصامت
# Original road count: مغيرا
# Original road count: جلود
# Original road count: Zaeid Al Kaeel
# Original road count: فتح الله الشافعي
# Original road count: علي الاسفراييني
# Original road count: السباق
# Original road count: Abdullah Bin Erdees
# Original road count: شارع بخاري
# Original road count: Al Gholeib
# Original road count: أصيل الدين أحمد بن محمد
# Original road count: حسين بواح زباني
# Original road count: شارع الشيخ عبدالله بن جبرين
# Original road count: جابر بن رحمة
# Original road count: شارع ساجر الرفدي
# Original road count: بيروت
# Original road count: طريق أبي بكر الصديق
# Original road count: 76
# Original road count: تاج الأمناء
# Original road count: 94
# Original road count: محمد بن سلامة الكرخي
# Original road count: دار الغنام
# Original road count: شارع الموسم
# Original road count: حمزة الزيات
# Original road count: شارع حفصه بن سيرين
# Original road count: الساهرية
# Original road count: الليث بن سعد
# Original road count: Dar Al Khalil
# Original road count: شارع أبي العودة
# Original road count: الأقزاز
# Original road count: مسعود بن سارية
# Original road count: مسلمة الفهري
# Original road count: شارع أسماء بن ربان بن معاوية
# Original road count: حمود الشغدلي
# Original road count: Aafeef uldin Al Qatan
# Original road count: جاكارتا
# Original road count: Mohamed Ibn Hamd Ibn Faris
# Original road count: وادي فاطمة
# Original road count: الأبيض بن معاوية
# Original road count: 5
# Original road count: Al Qoweiya
# Original road count: As Samah Bin Malik
# Original road count: علقة
# Original road count: دار المجد
# Original road count: علي بن عمر الحمامي
# Original road count: طريق الدوادمي البجادية
# Original road count: خليفة بن بديع
# Original road count: الجاحظ
# Original road count: هبة الله بن حامد
# Original road count: عبدالفتاح راوه
# Original road count: بكر بن هوزان
# Original road count: غرسة
# Original road count: Al Nibras
# Original road count: الجنابين
# Original road count: الغمر
# Original road count: مرسى الزيتونة
# Original road count: ابن نصرالله
# Original road count: مصطفي قيم زادة
# Original road count: واسط
# Original road count: الغاط
# Original road count: البجع
# Original road count: 355
# Original road count: الجيزاوي
# Original road count: ذات الأصلاب
# Original road count: ربيعة بن خويلد
# Original road count: Airport Road
# Original road count: أمية بن عبدالله الأموي
# Original road count: عبدالملك بن أبي علي
# Original road count: غالب المحاربي
# Original road count: أبي رميث
# Original road count: السنوسية
# Original road count: محمد بن الحاجب
# Original road count: ممر الكديد
# Original road count: كردفان
# Original road count: خلف الحريري
# Original road count: محمد بن عبدالرحمن بن مسيند
# Original road count: Nasr Allah Al Kindi
# Original road count: المقدم
# Original road count: يونس الصعيدي
# Original road count: سد مأرب
# Original road count: علي البنيان
# Original road count: قدير
# Original road count: أبي المغافر الحموي
# Original road count: Shaheed Al Din Thum Al Watan Ghadir Mohammed Abdullah AlAatfi AlQhtani
# Original road count: المهلب بن أبي صفرة
# Original road count: إسماعيل المؤذن
# Original road count: الينبوع
# Original road count: حذارق
# Original road count: محمد رؤوف
# Original road count: Innovation Street
# Original road count: الشيخ عبدالله أبابطين
# Original road count: Aal Rais
# Original road count: شارع على بن أبي طالب
# Original road count: سويد بن هبيرة
# Original road count: زلول
# Original road count: شاكر بن فضائل
# Original road count: زيد الموشكي
# Original road count: مرج الخليج
# Original road count: عماير الروضي
# Original road count: بواط
# Original road count: الخنسة
# Original road count: ذاكر بن الخفاف
# Original road count: Abi Umamah All Ansari St.
# Original road count: ابن صافي
# Original road count: علي بن مجثل المغيدي
# Original road count: جامع التميمي
# Original road count: أبي رواث
# Original road count: حسن الضمدي
# Original road count: أبي تراب اللوزي
# Original road count: شارع الإنشراح
# Original road count: شمس الدين آصف خان
# Original road count: محمد أبي الخير الفاسي
# Original road count: شارع بن احمد ابي الازهر
# Original road count: حسين بيهم
# Original road count: شارع الفرعة
# Original road count: عيسى بن جعفر
# Original road count: التعاطف
# Original road count: أبي عمرو الياسري
# Original road count: موسى العبدوسي
# Original road count: Abi Hafs Al Saffar
# Original road count: شارع سبط العفيف
# Original road count: نهر النيل
# Original road count: إسماعيل حقي
# Original road count: Afif
# Original road count: أبي عزيز قتادة
# Original road count: حصين بن سبرة
# Original road count: شارع مصعب الزبيري
# Original road count: الفتح بن خاقان
# Original road count: سهل بن سعد
# Original road count: Akeela
# Original road count: دار هذيل
# Original road count: شارع الشيخ عيسى بن سلمان آل خليفة
# Original road count: شوكان

# %%
with open("cleaned_unique_road_names.txt", "w") as f:
    for road_name in cleaned_roads:
        f.write(f"{road_name}\n")

# %% [markdown]
# ## Filter Depend on Ratio/Distance of Roads

# %%
with open("cleaned_unique_road_names.txt", "r") as f:
    cleaned_roads = set(line.strip() for line in f)

# %%
def get_road_start_end(gmaps_client, road_name, city='Riyadh'):
    try:
        geocode_result = gmaps_client.geocode(f"{road_name}, {city}")
        if geocode_result and 'bounds' in geocode_result[0]['geometry']:
            start_point = geocode_result[0]['geometry']['bounds']['northeast']
            end_point = geocode_result[0]['geometry']['bounds']['southwest']
            return (start_point['lat'], start_point['lng']), (end_point['lat'], end_point['lng'])
        else:
            return None, None
    except Exception as e:
        print(f"Error getting start/end points for {road_name}: {e}")
        return None, None

# %%
def determine_traffic_condition(speed_kmh, delay_min):
    if speed_kmh < 20 and delay_min > 10:
        return 'Heavy Traffic'
    elif speed_kmh < 40:
        return 'Moderate Traffic'
    else:
        return 'Light Traffic'

def get_traffic_data(gmaps_client, road_name, city='Riyadh'):
    start_coords, end_coords = get_road_start_end(gmaps_client, road_name, city)
    
    if start_coords is None or end_coords is None:
        print(f"Could not retrieve start/end points for {road_name}.")
        return None

    origin = f"{start_coords[0]},{start_coords[1]}"
    destination = f"{end_coords[0]},{end_coords[1]}"
    
    try:
        directions_result = gmaps_client.directions(
            origin,
            destination,
            mode="driving",
            departure_time="now",
            traffic_model="best_guess"
        )

        if directions_result:
            route = directions_result[0]['legs'][0]
            duration_in_traffic_min = route['duration_in_traffic']['value'] / 60
            duration_min = route['duration']['value'] / 60
            distance_km = route['distance']['value'] / 1000
            speed_kmh = (distance_km) / (duration_in_traffic_min / 60)
            delay_min = (route['duration_in_traffic']['value'] - route['duration']['value']) / 60
            traffic_ratio = duration_in_traffic_min / duration_min
            timestamp = datetime.now().isoformat()
            day_of_week = datetime.now().strftime('%A')
            hour_of_day = datetime.now().hour
            is_peak_hour = 1 if hour_of_day in range(7, 10) or hour_of_day in range(17, 20) else 0
            time_of_day = datetime.now().strftime('%p')
            traffic_condition = determine_traffic_condition(speed_kmh, delay_min)

            traffic_data = {
                'route_id': f"{road_name}_{datetime.now().strftime('%Y%m%d%H%M%S')}",
                'road_name': road_name,
                'origin': origin,
                'destination': destination,
                'distance_km': distance_km,
                'duration_min': duration_min,
                'duration_in_traffic_min': duration_in_traffic_min,
                'departure_time': timestamp,
                'speed_kmh': speed_kmh,
                'delay_min': delay_min,
                'traffic_ratio': traffic_ratio,
                'timestamp': timestamp,
                'day_of_week': day_of_week,
                'hour_of_day': hour_of_day,
                'is_peak_hour': is_peak_hour,
                'time_of_day': time_of_day,
                'traffic_condition': traffic_condition
            }
            return traffic_data
        else:
            return None
    except Exception as e:
        print(f"Error fetching traffic data for {road_name}: {e}")
        return None

def generate_data_for_first_10_roads(csv_file, gmaps_client):
    df = pd.read_csv(csv_file)
    origins_destinations = df['Road Name'].head(10).tolist()  
    traffic_data_list = []

    for road_name in origins_destinations:
        traffic_data = get_traffic_data(gmaps_client, road_name, city='Riyadh')  
        if traffic_data:
            traffic_data_list.append(traffic_data)

    traffic_df = pd.DataFrame(traffic_data_list)

    traffic_df.to_csv('test_traffic_data.csv', index=False)
    print("Traffic data for the first 10 roads saved to 'test_traffic_data.csv'.")
    
generate_data_for_first_10_roads('filtered_road_names.csv', gmaps)
# Out:
# Traffic data for the first 10 roads saved to 'test_traffic_data.csv'.

# %%
df = pd.DataFrame(top_200_heap, columns=['Negative Ratio', 'Road Name', 'Distance (km)', 'Time (mins)'])

df['Ratio (km/min)'] = -df['Negative Ratio']

df = df.drop(columns=['Negative Ratio'])

df.to_csv('filtered_road_names.csv', index=False)

print(f"Data saved to filtered_road_names.csv")
# Out:
# Data saved to filtered_road_names.csv

# %% [markdown]
# ## Add start,end points to csv

# %%
df = pd.read_csv('filtered_road_names.csv')
df.head()
# Out:
#                    Road Name  Distance (km)  Time (mins)  Ratio (km/min)
# 0                    العجلية        156.233    86.000000        1.816663
# 1  طريق الأرطاوية أم الجماجم        201.086   112.266667        1.791146
# 2                شارع برودان        352.026   196.200000        1.794220
# 3                   القويعية         17.266     9.700000        1.780000
# 4                      صلبوخ         36.323    25.416667        1.429102

# %%
df[['Start_point','End_point']] = df['Road Name'].apply(lambda x: pd.Series(get_road_start_end(gmaps, x, city='Riyadh')))

# %%
df.to_csv('filtered_road_names.csv', index=False)
